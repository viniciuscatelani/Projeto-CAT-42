# %%
# Importação das bibliotecas necessárias

import pandas as pd
import numpy as np
import glob
import math

# %%
# Definição da loja a ser utilizada

loja = 191

# %%
# Leitura do arquivo de entradas-operação própria

file_1 = pd.read_csv(f"Loja_{loja}/nfe_entrada_oppropr.txt",sep = '\t', header=1, encoding='utf-8')
file_1.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão', 'Número item', 'Código Produto ou Serviço'
# 'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço', 'Valor ICMS Operação'
# 'Valor ICMS Substituição Tributária','', 'Valor Base Cálculo ICMS ST Retido Operação Anterior'
# 'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM'
# 'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)'
# 'Número CNPJ Destinatário (char)'
# Out:
#                                Chave Acesso NFe  Código CFOP (04 Posições)  \
# 0  35180771605265002105550020000000021138803433                       1411
# 1  35180771605265002105550020000000031138855538                       1411
# 2  35180771605265002105550020000000031138855538                       1411
# 3  35180771605265002105550020000000031138855538                       1411
# 4  35180771605265002105550020000000031138855538                       1411
#
#                Descrição Produto  Número Item Data Emissão Unidade Comercial  \
# 0      Diclof Sodio Med 50mg 20S            1   27/07/2018            UN
# 1         Decongex Plus 12S Ache            3   30/07/2018            UN
# 2         Decongex Plus 12S Ache            4   30/07/2018            UN
# 3  Luftal Max 125mg Gel 10S Bm/O            1   30/07/2018            UN
# 4  Luftal Max 125mg Gel 10S Bm/O            2   30/07/2018            UN
#
#    Número CNPJ Destinatário  Número CNPJ Emitente  Código NCM Cod UF Emitente  \
# 0              7.160527e+13        71605265002105    30049037              SP
# 1              7.160527e+13        71605265002105    30049099              SP
# 2              7.160527e+13        71605265002105    30049099              SP
# 3              7.160527e+13        71605265002105    30049099              SP
# 4              7.160527e+13        71605265002105    30049099              SP
#
#    ... Valor ICMS  Valor ICMS Substituição Tributária  \
# 0  ...        NaN                                 NaN
# 1  ...        NaN                                 NaN
# 2  ...        NaN                                 NaN
# 3  ...        NaN                                 NaN
# 4  ...        NaN                                 NaN
#
#    Valor ICMS Substituição Tributária Destino  Valor Total NFE do Produto  \
# 0                                         NaN                        9,03
# 1                                         NaN                       16,27
# 2                                         NaN                       16,27
# 3                                         NaN                       17,64
# 4                                         NaN                       17,64
#
#   Valor Total Tributo Valor Desconto Incondicional  \
# 0                 2,9                          NaN
# 1                4,28                          NaN
# 2                4,28                          NaN
# 3                4,64                          NaN
# 4                4,64                          NaN
#
#    Valor Desconto Condicional Valor ICMS Substituto  Valor Frete  Valor Seguro
# 0                         NaN                   NaN          NaN           NaN
# 1                         NaN                   NaN          NaN           NaN
# 2                         NaN                   NaN          NaN           NaN
# 3                         NaN                   NaN          NaN           NaN
# 4                         NaN                   NaN          NaN           NaN
#
# [5 rows x 41 columns]

# %%
file_1.columns
# Out:
# Index(['Chave Acesso NFe', 'Código CFOP (04 Posições)', 'Descrição Produto',
#        'Número Item', 'Data Emissão', 'Unidade Comercial',
#        'Número CNPJ Destinatário', 'Número CNPJ Emitente', 'Código NCM',
#        'Cod UF Emitente', 'Cod UF Destinatário',
#        'Documento Fiscal.Número CNPJ Emitente (char)',
#        'Documento Fiscal Produto.Número CNPJ Emitente (char)',
#        'Número CNPJ Destinatário (char)',
#        'Descrição Informações Adicionais Produto (original)',
#        'Descrição Informações Adicionais Produto',
#        'Indicador Tipo Documento Fiscal',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior', 'Código CEST',
#        'Código CEST (char)', 'Código GTIN', 'Código Produto ou Serviço',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Destino', 'Quantidade Comercial',
#        'Quantidade Tributável', 'Valor ICMS FCP ST Retido',
#        'Valor Percentual FCP ST Retido', 'Valor Base Cálculo FCP ST Retido',
#        'Valor ICMS ST Retido Operação Anterior', 'Valor Produto ou Serviço',
#        'Valor ICMS', 'Valor ICMS Substituição Tributária',
#        'Valor ICMS Substituição Tributária Destino',
#        'Valor Total NFE do Produto', 'Valor Total Tributo',
#        'Valor Desconto Incondicional', 'Valor Desconto Condicional',
#        'Valor ICMS Substituto', 'Valor Frete', 'Valor Seguro'],
#       dtype='object')

# %%
# Seleção das colunas necessárias do
# arquivo entradas-operação própria

file_1_new = file_1.copy()
file_1_new = file_1_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item', 'Código Produto ou Serviço',
                    'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                    'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                    'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                    'Unidade Comercial', 'Código NCM',
                    'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)',
                    'Número CNPJ Destinatário (char)']]

file_1_new['Tipo'] = ['entrada_oprprp']*len(file_1_new)

file_1_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35180771605265002105550020000000021138803433   27/07/2018            1
# 1  35180771605265002105550020000000031138855538   30/07/2018            3
# 2  35180771605265002105550020000000031138855538   30/07/2018            4
# 3  35180771605265002105550020000000031138855538   30/07/2018            1
# 4  35180771605265002105550020000000031138855538   30/07/2018            2
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     37127                       1411               1,0000
# 1                     12914                       1411               1,0000
# 2                     12914                       1411               1,0000
# 3                     17921                       1411               1,0000
# 4                     17921                       1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS  Valor ICMS Substituição Tributária  \
# 0                    18,07        NaN                                 NaN
# 1                    21,09        NaN                                 NaN
# 2                    21,09        NaN                                 NaN
# 3                    23,34        NaN                                 NaN
# 4                    23,34        NaN                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                               10,3
# 1                                              18,03
# 2                                              18,03
# 3                                              20,22
# 4                                              20,22
#
#                Descrição Produto     Código GTIN Unidade Comercial  \
# 0      Diclof Sodio Med 50mg 20S  7896422504492             UN
# 1         Decongex Plus 12S Ache  7896658001901             UN
# 2         Decongex Plus 12S Ache  7896658001901             UN
# 3  Luftal Max 125mg Gel 10S Bm/O  7896016804939             UN
# 4  Luftal Max 125mg Gel 10S Bm/O  7896016804939             UN
#
#    Código NCM  Código CEST  Documento Fiscal.Número CNPJ Emitente (char)  \
# 0    30049037    1300200.0                                71605265002105
# 1    30049099    1300101.0                                71605265002105
# 2    30049099    1300101.0                                71605265002105
# 3    30049099    1300101.0                                71605265002105
# 4    30049099    1300101.0                                71605265002105
#
#    Número CNPJ Destinatário (char)            Tipo
# 0                   71605265002105  entrada_oprprp
# 1                   71605265002105  entrada_oprprp
# 2                   71605265002105  entrada_oprprp
# 3                   71605265002105  entrada_oprprp
# 4                   71605265002105  entrada_oprprp

# %%
# Leitura do arquivo de entradas- outras entradas
# (entradas de outros estados que não SP)

file_2 = pd.read_csv(f"Loja_{loja}/nfe_entrada_outras.txt", sep='\t', header=1, encoding = 'utf-8')
file_2.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão','Número Item', 'Número CNPJ Emitente (char)',
# 'Número CNPJ Destinatário (char)', 'Código GTIN', 'Código NCM',
# 'Descrição Produto', 'Código CFOP (04 Posições)', 'Unidade Comercial',
# 'Valor Base Cálculo ICMS Substituição Tributária', 'Valor ICMS ST Retido Operação Anterior',
# 'Código Produto ou Serviço', 'Código CEST (char)'
# Out:
#                             Chave Acesso Nota Fiscal  \
# 0  50.190.607.259.917.000.000.000.000.000.000.000...
# 1  50.190.607.259.917.000.000.000.000.000.000.000...
# 2  50.190.607.259.917.000.000.000.000.000.000.000...
# 3  50.190.607.259.917.000.000.000.000.000.000.000...
# 4  50.190.707.259.917.000.000.000.000.000.000.000...
#
#                                Chave Acesso NFe  Referencia Mês Emissão  \
# 0  50190607259917000154550010000038171870938380                 201.906
# 1  50190607259917000154550010000038171870938380                 201.906
# 2  50190607259917000154550010000038171870938380                 201.906
# 3  50190607259917000154550010000038171870938380                 201.906
# 4  50190707259917000154550010000047571873769161                 201.907
#
#   Data Emissão  Indicador Situação Documento Fiscal  \
# 0    30/6/2019                                    0
# 1    30/6/2019                                    0
# 2    30/6/2019                                    0
# 3    30/6/2019                                    0
# 4     7/7/2019                                    0
#
#    Indicador Tipo Documento Fiscal  Número CNPJ Emitente (char)  \
# 0                                1                7259917000154
# 1                                1                7259917000154
# 2                                1                7259917000154
# 3                                1                7259917000154
# 4                                1                7259917000154
#
#    Número CNPJ Destinatário (char)  Número Item  Código NCM  ... Código Barra  \
# 0                   71605265002105            1    85235990  ...          NaN
# 1                   71605265002105            2    85235990  ...          NaN
# 2                   71605265002105            3    85235990  ...          NaN
# 3                   71605265002105            4    85235990  ...          NaN
# 4                   71605265002105            1    85235990  ...          NaN
#
#    Código CEST Código CEST (char) Valor ICMS Operação Valor ICMS Diferido  \
# 0          NaN                NaN                 NaN                 NaN
# 1          NaN                NaN                 NaN                 NaN
# 2          NaN                NaN                 NaN                 NaN
# 3          NaN                NaN                 NaN                 NaN
# 4          NaN                NaN                 NaN                 NaN
#
#    Valor Desconto Incondicionado  Valor Desconto Condicionado  Valor Outro  \
# 0                            NaN                          NaN          NaN
# 1                            NaN                          NaN          NaN
# 2                            NaN                          NaN          NaN
# 3                            NaN                          NaN          NaN
# 4                            NaN                          NaN          NaN
#
#    Valor Dedução  Quantidade Comercial
# 0            NaN              320,0000
# 1            NaN              195,0000
# 2            NaN              472,0000
# 3            NaN              214,0000
# 4            NaN              760,0000
#
# [5 rows x 48 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-outras entradas

file_2_new = file_2.copy()
file_2_new = file_2_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Tributável','Valor Produto ou Serviço','Valor ICMS Operação',
                         'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                         'Unidade Comercial','Código NCM','Código CEST (char)',
                         'Número CNPJ Emitente (char)','Número CNPJ Destinatário (char)']]

file_2_new['Tipo'] = ['entrada_outras']*len(file_2_new)
file_2_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  50190607259917000154550010000038171870938380    30/6/2019            1
# 1  50190607259917000154550010000038171870938380    30/6/2019            2
# 2  50190607259917000154550010000038171870938380    30/6/2019            3
# 3  50190607259917000154550010000038171870938380    30/6/2019            4
# 4  50190707259917000154550010000047571873769161     7/7/2019            1
#
#    Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Tributável  \
# 0                10010000000                      6.949              320,0000
# 1                10050000000                      6.949              195,0000
# 2                10030000000                      6.949              472,0000
# 3                10040000000                      6.949              214,0000
# 4                10010000000                      6.949              760,0000
#
#   Valor Produto ou Serviço  Valor ICMS Operação  \
# 0                    307,2                  NaN
# 1                   189,15                  NaN
# 2                   457,84                  NaN
# 3                   205,44                  NaN
# 4                    729,6                  NaN
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior Descrição Produto  \
# 0                                                NaN          ONLINE TIM
# 1                                                NaN           ONLINE OI
# 2                                                NaN        ONLINE CLARO
# 3                                                NaN         ONLINE VIVO
# 4                                                NaN          ONLINE TIM
#
#       Código GTIN Unidade Comercial  Código NCM  Código CEST (char)  \
# 0  SEM GTIN                  UN        85235990                 NaN
# 1  SEM GTIN                  UN        85235990                 NaN
# 2  SEM GTIN                  UN        85235990                 NaN
# 3  SEM GTIN                  UN        85235990                 NaN
# 4  SEM GTIN                  UN        85235990                 NaN
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)  \
# 0                7259917000154                   71605265002105
# 1                7259917000154                   71605265002105
# 2                7259917000154                   71605265002105
# 3                7259917000154                   71605265002105
# 4                7259917000154                   71605265002105
#
#              Tipo
# 0  entrada_outras
# 1  entrada_outras
# 2  entrada_outras
# 3  entrada_outras
# 4  entrada_outras

# %%
# Leitura do arquivo de entradas- entradas SP
# (entradas de SP)


file_3 = pd.read_csv(f"Loja_{loja}/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
file_3.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Código CEST', 'Código CFOP (04 Posições)'
# 'Descrição Produto', 'Código Produto ou Serviço', 'Número Item', 'Data Emissão'
# 'Unidade Comercial', 'Número CNPJ Emitente', 'Número CNPJ Destinatário (char)'
# 'Código NCM', 'Código GTIN', 'Quantidade Comercial', 'Valor ICMS ST Retido Operação Anterior'
# 'Valor Produto ou Serviço', 'Valor ICMS Substituição Tributária'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_13336\369719733.py:5: DtypeWarning: Columns (5,21,22,31,32,34,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_3 = pd.read_csv(f"Loja_{loja}/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
#                                Chave Acesso NFe  Código CEST  \
# 0  35180612051422000175550010000024311169586348          NaN
# 1  35180612051422000175550010000024311169586348          NaN
# 2  35180612051422000175550010000024311169586348          NaN
# 3  35180612051422000175550010000024311169586348          NaN
# 4  35180612051422000175550010000024311169586348          NaN
#
#    Código CEST (char)  Código CFOP (04 Posições)  \
# 0                 NaN                       5922
# 1                 NaN                       5922
# 2                 NaN                       5922
# 3                 NaN                       5922
# 4                 NaN                       5922
#
#                                    Descrição Produto  \
# 0  BALCAO CAIXA LINHA PLUS 900 X 1000 X 500MM - A...
# 1   BALCAO TERMINAL LINHA PLUS ALUMINIO 486X1000X400
# 2                   BANDEIROLA AÇO CHANFRADA 920X220
# 3              CANTO DUPLO EM MDF - 3 FACES - 2385MM
# 4                  CESTO COMPRIMIDEIRO 1000 2S + 1PE
#
#   Código Produto ou Serviço  Número Item Data Emissão Unidade Comercial  \
# 0                     00035            9   28/06/2018            Uni.
# 1                     00087           10   28/06/2018            Uni.
# 2                     00652           14   28/06/2018            Uni.
# 3                     00059           11   28/06/2018            Uni.
# 4                       688           18   28/06/2018            Uni.
#
#    Número CNPJ Emitente  ...  Valor ICMS  Valor ICMS Substituição Tributária  \
# 0        12051422000175  ...         NaN                                 NaN
# 1        12051422000175  ...         NaN                                 NaN
# 2        12051422000175  ...         NaN                                 NaN
# 3        12051422000175  ...         NaN                                 NaN
# 4        12051422000175  ...         NaN                                 NaN
#
#   Valor ICMS Substituição Tributária Destino Valor Total NFE do Produto  \
# 0                                        NaN                   1.475,25
# 1                                        NaN                     698,25
# 2                                        NaN                      1.722
# 3                                        NaN                   1.086,75
# 4                                        NaN                      850,5
#
#   Valor Total Tributo Valor Desconto Incondicional Valor Desconto Condicional  \
# 0                 NaN                          NaN                        NaN
# 1                 NaN                          NaN                        NaN
# 2                 NaN                          NaN                        NaN
# 3                 NaN                          NaN                        NaN
# 4                 NaN                          NaN                        NaN
#
#   Valor ICMS Substituto Valor Frete Valor Seguro
# 0                   NaN         NaN          NaN
# 1                   NaN         NaN          NaN
# 2                   NaN         NaN          NaN
# 3                   NaN         NaN          NaN
# 4                   NaN         NaN          NaN
#
# [5 rows x 40 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-entradas SP

file_3_new = file_3.copy()
file_3_new = file_3_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS', 
                         'Valor ICMS Substituição Tributária','Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior',
                         'Descrição Produto','Código GTIN','Unidade Comercial','Código NCM',
                         'Código CEST','Número CNPJ Emitente', 'Número CNPJ Destinatário (char)']]

file_3_new['Tipo'] = ['entrada_sp']*len(file_3_new)

file_3_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35180612051422000175550010000024311169586348   28/06/2018            9
# 1  35180612051422000175550010000024311169586348   28/06/2018           10
# 2  35180612051422000175550010000024311169586348   28/06/2018           14
# 3  35180612051422000175550010000024311169586348   28/06/2018           11
# 4  35180612051422000175550010000024311169586348   28/06/2018           18
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     00035                       5922               1,0000
# 1                     00087                       5922               1,0000
# 2                     00652                       5922               8,0000
# 3                     00059                       5922               3,0000
# 4                       688                       5922               6,0000
#
#   Valor Produto ou Serviço Valor ICMS Valor ICMS Substituição Tributária  \
# 0                    1.405        NaN                                NaN
# 1                      665        NaN                                NaN
# 2                    1.640        NaN                                NaN
# 3                    1.035        NaN                                NaN
# 4                      810        NaN                                NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Descrição Produto     Código GTIN  \
# 0  BALCAO CAIXA LINHA PLUS 900 X 1000 X 500MM - A...
# 1   BALCAO TERMINAL LINHA PLUS ALUMINIO 486X1000X400
# 2                   BANDEIROLA AÇO CHANFRADA 920X220
# 3              CANTO DUPLO EM MDF - 3 FACES - 2385MM
# 4                  CESTO COMPRIMIDEIRO 1000 2S + 1PE
#
#   Unidade Comercial  Código NCM  Código CEST  Número CNPJ Emitente  \
# 0            Uni.      94036000          NaN        12051422000175
# 1            Uni.      94036000          NaN        12051422000175
# 2            Uni.      94032000          NaN        12051422000175
# 3            Uni.      94036000          NaN        12051422000175
# 4            Uni.      94032000          NaN        12051422000175
#
#    Número CNPJ Destinatário (char)        Tipo
# 0                   71605265002105  entrada_sp
# 1                   71605265002105  entrada_sp
# 2                   71605265002105  entrada_sp
# 3                   71605265002105  entrada_sp
# 4                   71605265002105  entrada_sp

# %%
# Leitura do arquivo de saídas-dfe

file_4 = pd.read_csv(f'Loja_{loja}/dfe.txt', encoding='utf-8', sep='\t', header=1,quoting=3, error_bad_lines=False)
#file_4_2 = pd.read_table('Loja_26/dfe2.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)

#file_4 = pd.concat([file_4_1, file_4_2])
file_4.head()

# Colunas a serem usadas:
# 'Descrição Produto', 'Código EAN', 'Código Produto', 'Chave CF-e', 'Unidade Comercial'
# 'Número Item', 'Código CFOP 04 Posições', 'Data Emissao', 'Quantidade Comercial'
# 'Valor Item'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_13336\4095308912.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   file_4 = pd.read_csv(f'Loja_{loja}/dfe.txt', encoding='utf-8', sep='\t', header=1,quoting=3, error_bad_lines=False)
# C:\Users\vinic\AppData\Local\Temp\ipykernel_13336\4095308912.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_4 = pd.read_csv(f'Loja_{loja}/dfe.txt', encoding='utf-8', sep='\t', header=1,quoting=3, error_bad_lines=False)
#                        Descrição Produto  Código CEST    Código EAN  \
# 0  10263 - CLOR CICLOBENZAP CIMED 10MG 3          NaN  7.896523e+12
# 1  10263 - LEVOTIROXINA SOD 112MCG 30S M          NaN  7.891721e+12
# 2  10263 - LEVOTIROXINA SOD 112MCG 30S M          NaN  7.891721e+12
# 3     10263 - LOSARTANA POT LEG 50MG 30S          NaN  7.894916e+12
# 4     10263 - LOSARTANA POT LEG 50MG 30S          NaN  7.894916e+12
#
#    Código Produto                                    Chave CF-e  \
# 0          178996  35200571605265002105590003512550499669092091
# 1          910786  35200571605265002105590003512550499669092091
# 2          910786  35200571605265002105590003512550499669092091
# 3          139899  35200571605265002105590003512550499669092091
# 4          139899  35200571605265002105590003512550499669092091
#
#   Unidade Comercial  Número Item  Código CFOP 04 Posições  \
# 0                UN            1                     5405
# 1                UN            2                     5405
# 2                UN            3                     5405
# 3                UN            5                     5405
# 4                UN            6                     5405
#
#   Informações Adicicionais       Num Cnpj Emit Data Emissao Valor Produtos  \
# 0                      NaN  71.605.265/0021-05    5/14/2020          19,54
# 1                      NaN  71.605.265/0021-05    5/14/2020          14,93
# 2                      NaN  71.605.265/0021-05    5/14/2020          14,93
# 3                      NaN  71.605.265/0021-05    5/14/2020          13,34
# 4                      NaN  71.605.265/0021-05    5/14/2020          13,34
#
#   Valor Icms Quantidade Comercial Valor Item Valor Unitário Comercialização  \
# 0        NaN               1,0000      15,63                         19,540
# 1        NaN               1,0000      11,35                         14,930
# 2        NaN               1,0000      11,35                         14,930
# 3        NaN               1,0000       7,85                         13,340
# 4        NaN               1,0000       7,85                         13,340
#
#   Valor Desconto  Valor Outro  Valor Rateio Desconto  Valor Rateio Acrescimo
# 0           3,91          NaN                    NaN                     NaN
# 1           3,58          NaN                    NaN                     NaN
# 2           3,58          NaN                    NaN                     NaN
# 3           5,49          NaN                    NaN                     NaN
# 4           5,49          NaN                    NaN                     NaN

# %%
# Seleção das colunas necessárias
# do arquivos saídas-dfe

file_4_new = file_4.copy()
file_4_new = file_4_new[['Chave CF-e', 'Data Emissao', 'Número Item',
                        'Código Produto', 'Código CFOP 04 Posições','Valor Icms',
                        'Quantidade Comercial', 'Valor Item','Descrição Produto','Código EAN',
                        'Unidade Comercial', 'Código CEST']]

file_4_new['Tipo'] = ['dfe']*len(file_4_new)

file_4_new.head()
# Out:
#                                      Chave CF-e Data Emissao  Número Item  \
# 0  35200571605265002105590003512550499669092091    5/14/2020            1
# 1  35200571605265002105590003512550499669092091    5/14/2020            2
# 2  35200571605265002105590003512550499669092091    5/14/2020            3
# 3  35200571605265002105590003512550499669092091    5/14/2020            5
# 4  35200571605265002105590003512550499669092091    5/14/2020            6
#
#    Código Produto  Código CFOP 04 Posições Valor Icms Quantidade Comercial  \
# 0          178996                     5405        NaN               1,0000
# 1          910786                     5405        NaN               1,0000
# 2          910786                     5405        NaN               1,0000
# 3          139899                     5405        NaN               1,0000
# 4          139899                     5405        NaN               1,0000
#
#   Valor Item                      Descrição Produto    Código EAN  \
# 0      15,63  10263 - CLOR CICLOBENZAP CIMED 10MG 3  7.896523e+12
# 1      11,35  10263 - LEVOTIROXINA SOD 112MCG 30S M  7.891721e+12
# 2      11,35  10263 - LEVOTIROXINA SOD 112MCG 30S M  7.891721e+12
# 3       7,85     10263 - LOSARTANA POT LEG 50MG 30S  7.894916e+12
# 4       7,85     10263 - LOSARTANA POT LEG 50MG 30S  7.894916e+12
#
#   Unidade Comercial  Código CEST Tipo
# 0                UN          NaN  dfe
# 1                UN          NaN  dfe
# 2                UN          NaN  dfe
# 3                UN          NaN  dfe
# 4                UN          NaN  dfe

# %%
# Leitura do arquivo de saídas- nfe saídas

file_5 = pd.read_csv(f'Loja_{loja}/nfe_saidas.txt', encoding='utf-8', sep='\t', header=1)
file_5.head()

# Colunas a serem usadas:
# 'Data Emissão', 'Chave Acesso NFe', 'Código GTIN', 'Número Item'
# 'Código Produto ou Serviço', 'Descrição Produto', 'Código NCM'
# 'Código CFOP (04 Posições)', 'Unidade Comercial', 'Número CNPJ Destinatário (char)'
# 'Número CNPJ Emitente (char)', 'Quantidade Comercial', 'Valor Produto ou Serviço'
# Out:
#   Data Emissão                              Chave Acesso NFe  Código CEST  \
# 0   31/07/2018  35180771605265002105550020000000121009399535    1300100.0
# 1   31/07/2018  35180771605265002105550020000000131009619168    2804100.0
# 2   01/08/2018  35180871605265002105550020000000141138953197    2804100.0
# 3   02/08/2018  35180871605265002105550020000000161138973222     300600.0
# 4   02/08/2018  35180871605265002105550020000000161138973222    1300201.0
#
#       Código GTIN  Código CEST (char)  Número Item Código Produto ou Serviço  \
# 0  7896026302999            1300100.0            1                    902882
# 1  7898623352483            2804100.0            1                    176610
# 2  7898157492501            2804100.0            1                     36459
# 3  7898623353954             300600.0            3                    199968
# 4  7894916145565            1300201.0            1                    140889
#
#                 Descrição Produto    Descrição Produto (original)  Código NCM  \
# 0  Spiriva Respimat 2,5mcg 4ml Bo  Spiriva Respimat 2,5mcg 4ml Bo    30044990
# 1           Vitacon Mater 60S Mcg           Vitacon Mater 60S Mcg    21069030
# 2  Manteiga De Cacau Bast Lebl/Fc  Manteiga De Cacau Bast Lebl/Fc    33049990
# 3  AGUA GARRAFA 510ML C/G F.CONDE  AGUA GARRAFA 510ML C/G F.CONDE    22011000
# 4      DESLORATADINA LEG XPE 60ML      DESLORATADINA LEG XPE 60ML    30049099
#
#    ...  Valor ICMS Substituição Tributária  \
# 0  ...                                 NaN
# 1  ...                                 NaN
# 2  ...                                 NaN
# 3  ...                                 NaN
# 4  ...                                 NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              259,9
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Valor ICMS ST Retido Operação Anterior Valor Total Tributo  \
# 0                                   22,29                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
#
#   Valor Total NFE do Produto  Valor Outras Despesas Acessórias Valor Dedução  \
# 0                     193,46                               NaN           NaN
# 1                     119,84                               NaN           NaN
# 2                        295                               NaN           NaN
# 3                      29,88                               NaN           NaN
# 4                      124,8                               NaN           NaN
#
#   Valor Desconto Incondicional Valor Desconto Condicional
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 32 columns]

# %%
# Seleção das colunas necessárias
# do arquivo saídas - nfe saídas

file_5_new = file_5.copy()
file_5_new = file_5_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item',
                        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
                        'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                        'Descrição Produto','Código GTIN', 'Unidade Comercial',
                        'Código NCM','Código CEST', 'Número CNPJ Emitente (char)',
                        'Número CNPJ Destinatário (char)']]

file_5_new['Tipo'] = ['saida_nfe']*len(file_5_new)

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35180771605265002105550020000000121009399535   31/07/2018            1
# 1  35180771605265002105550020000000131009619168   31/07/2018            1
# 2  35180871605265002105550020000000141138953197   01/08/2018            1
# 3  35180871605265002105550020000000161138973222   02/08/2018            3
# 4  35180871605265002105550020000000161138973222   02/08/2018            1
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    902882                       5409               1,0000
# 1                    176610                       5152               4,0000
# 2                     36459                       5949             500,0000
# 3                    199968                       5411              36,0000
# 4                    140889                       5411              24,0000
#
#   Valor Produto ou Serviço Valor ICMS               Descrição Produto  \
# 0                   193,46        NaN  Spiriva Respimat 2,5mcg 4ml Bo
# 1                   119,84      21,57           Vitacon Mater 60S Mcg
# 2                      295        NaN  Manteiga De Cacau Bast Lebl/Fc
# 3                    29,88        NaN  AGUA GARRAFA 510ML C/G F.CONDE
# 4                    124,8        NaN      DESLORATADINA LEG XPE 60ML
#
#       Código GTIN Unidade Comercial  Código NCM  Código CEST  \
# 0  7896026302999             UN        30044990    1300100.0
# 1  7898623352483             UN        21069030    2804100.0
# 2  7898157492501             UN        33049990    2804100.0
# 3  7898623353954             UN        22011000     300600.0
# 4  7894916145565             UN        30049099    1300201.0
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)       Tipo
# 0               71605265002105                   71605265001486  saida_nfe
# 1               71605265002105                   71605265001486  saida_nfe
# 2               71605265002105                   71605265002105  saida_nfe
# 3               71605265002105                   27849963000110  saida_nfe
# 4               71605265002105                   27849963000110  saida_nfe

# %%
# Renomeação das colunas do dataframe
# de entradas

file_1_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Documento Fiscal.Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_1_new['Data Emissão'] = pd.to_datetime(file_1_new['Data Emissão'], format='%d/%m/%Y')
file_1_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_2_new.rename(
    columns={'Quantidade Tributável':'Quantidade Comercial',
            'Código CEST (char)':'Código CEST',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_2_new['Data Emissão'] = pd.to_datetime(file_2_new['Data Emissão'], format='%d/%m/%Y')
file_2_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_3_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_3_new['Data Emissão'] = pd.to_datetime(file_3_new['Data Emissão'], format='%d/%m/%Y')
file_3_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_4_new.rename(
    columns={'Chave CF-e':'Chave Acesso NFe',
            'Código Produto':'Código Produto ou Serviço',
            'Data Emissao':'Data Emissão',
             'Valor Icms': 'Valor ICMS Operação',
            'Código CFOP 04 Posições':'Código CFOP (04 Posições)',
            'Valor Item':'Valor Produto ou Serviço',
            'Código EAN': 'Código GTIN'}, inplace=True)

file_4_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Valor ICMS Operação', 'Quantidade Comercial',
#        'Valor Produto ou Serviço', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código CEST', 'Tipo'],
#       dtype='object')

# %%
file_4_new['Valor ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_4_new['Código NCM'] = np.nan
file_4_new['Número CNPJ Emitente'] = np.nan
file_4_new['Número CNPJ Destinatário'] = np.nan
file_4_new['Data Emissão'] = pd.to_datetime(file_4_new['Data Emissão'], format='%m/%d/%Y')
file_4_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35200571605265002105590003512550499669092091   2020-05-14            1
# 1  35200571605265002105590003512550499669092091   2020-05-14            2
# 2  35200571605265002105590003512550499669092091   2020-05-14            3
# 3  35200571605265002105590003512550499669092091   2020-05-14            5
# 4  35200571605265002105590003512550499669092091   2020-05-14            6
#
#    Código Produto ou Serviço  Código CFOP (04 Posições) Valor ICMS Operação  \
# 0                     178996                       5405                 NaN
# 1                     910786                       5405                 NaN
# 2                     910786                       5405                 NaN
# 3                     139899                       5405                 NaN
# 4                     139899                       5405                 NaN
#
#   Quantidade Comercial Valor Produto ou Serviço  \
# 0               1,0000                    15,63
# 1               1,0000                    11,35
# 2               1,0000                    11,35
# 3               1,0000                     7,85
# 4               1,0000                     7,85
#
#                        Descrição Produto   Código GTIN Unidade Comercial  \
# 0  10263 - CLOR CICLOBENZAP CIMED 10MG 3  7.896523e+12                UN
# 1  10263 - LEVOTIROXINA SOD 112MCG 30S M  7.891721e+12                UN
# 2  10263 - LEVOTIROXINA SOD 112MCG 30S M  7.891721e+12                UN
# 3     10263 - LOSARTANA POT LEG 50MG 30S  7.894916e+12                UN
# 4     10263 - LOSARTANA POT LEG 50MG 30S  7.894916e+12                UN
#
#    Código CEST Tipo  Valor ICMS Substituição Tributária  \
# 0          NaN  dfe                                 NaN
# 1          NaN  dfe                                 NaN
# 2          NaN  dfe                                 NaN
# 3          NaN  dfe                                 NaN
# 4          NaN  dfe                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  Código NCM  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#    Número CNPJ Emitente  Número CNPJ Destinatário
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN

# %%
file_5_new.rename(
    columns={'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_5_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código NCM', 'Código CEST',
#        'Número CNPJ Emitente', 'Número CNPJ Destinatário', 'Tipo'],
#       dtype='object')

# %%
file_5_new['Valor ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_5_new['Data Emissão'] = pd.to_datetime(file_5_new['Data Emissão'], format='%d/%m/%Y')

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35180771605265002105550020000000121009399535   2018-07-31            1
# 1  35180771605265002105550020000000131009619168   2018-07-31            1
# 2  35180871605265002105550020000000141138953197   2018-08-01            1
# 3  35180871605265002105550020000000161138973222   2018-08-02            3
# 4  35180871605265002105550020000000161138973222   2018-08-02            1
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    902882                       5409               1,0000
# 1                    176610                       5152               4,0000
# 2                     36459                       5949             500,0000
# 3                    199968                       5411              36,0000
# 4                    140889                       5411              24,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                   193,46                 NaN
# 1                   119,84               21,57
# 2                      295                 NaN
# 3                    29,88                 NaN
# 4                    124,8                 NaN
#
#                 Descrição Produto     Código GTIN Unidade Comercial  \
# 0  Spiriva Respimat 2,5mcg 4ml Bo  7896026302999             UN
# 1           Vitacon Mater 60S Mcg  7898623352483             UN
# 2  Manteiga De Cacau Bast Lebl/Fc  7898157492501             UN
# 3  AGUA GARRAFA 510ML C/G F.CONDE  7898623353954             UN
# 4      DESLORATADINA LEG XPE 60ML  7894916145565             UN
#
#    Código NCM  Código CEST  Número CNPJ Emitente  Número CNPJ Destinatário  \
# 0    30044990    1300100.0        71605265002105            71605265001486
# 1    21069030    2804100.0        71605265002105            71605265001486
# 2    33049990    2804100.0        71605265002105            71605265002105
# 3    22011000     300600.0        71605265002105            27849963000110
# 4    30049099    1300201.0        71605265002105            27849963000110
#
#         Tipo  Valor ICMS Substituição Tributária  \
# 0  saida_nfe                                 NaN
# 1  saida_nfe                                 NaN
# 2  saida_nfe                                 NaN
# 3  saida_nfe                                 NaN
# 4  saida_nfe                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
file_1_new = file_1_new.astype(str)
file_2_new = file_2_new.astype(str)
file_3_new = file_3_new.astype(str)
file_4_new = file_4_new.astype(str)
file_5_new = file_5_new.astype(str)

# %%
df_final = pd.concat([file_1_new, file_2_new, file_3_new, file_4_new, file_5_new])
df_final.head()
# Out:
#                                Chave Acesso NFe Data Emissão Número Item  \
# 0  35180771605265002105550020000000021138803433   2018-07-27           1
# 1  35180771605265002105550020000000031138855538   2018-07-30           3
# 2  35180771605265002105550020000000031138855538   2018-07-30           4
# 3  35180771605265002105550020000000031138855538   2018-07-30           1
# 4  35180771605265002105550020000000031138855538   2018-07-30           2
#
#   Código Produto ou Serviço Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     37127                      1411               1,0000
# 1                     12914                      1411               1,0000
# 2                     12914                      1411               1,0000
# 3                     17921                      1411               1,0000
# 4                     17921                      1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                    18,07                 nan
# 1                    21,09                 nan
# 2                    21,09                 nan
# 3                    23,34                 nan
# 4                    23,34                 nan
#
#   Valor ICMS Substituição Tributária  \
# 0                                nan
# 1                                nan
# 2                                nan
# 3                                nan
# 4                                nan
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                               10,3
# 1                                              18,03
# 2                                              18,03
# 3                                              20,22
# 4                                              20,22
#
#                Descrição Produto     Código GTIN Unidade Comercial Código NCM  \
# 0      Diclof Sodio Med 50mg 20S  7896422504492             UN       30049037
# 1         Decongex Plus 12S Ache  7896658001901             UN       30049099
# 2         Decongex Plus 12S Ache  7896658001901             UN       30049099
# 3  Luftal Max 125mg Gel 10S Bm/O  7896016804939             UN       30049099
# 4  Luftal Max 125mg Gel 10S Bm/O  7896016804939             UN       30049099
#
#   Código CEST Número CNPJ Emitente Número CNPJ Destinatário            Tipo
# 0   1300200.0       71605265002105           71605265002105  entrada_oprprp
# 1   1300101.0       71605265002105           71605265002105  entrada_oprprp
# 2   1300101.0       71605265002105           71605265002105  entrada_oprprp
# 3   1300101.0       71605265002105           71605265002105  entrada_oprprp
# 4   1300101.0       71605265002105           71605265002105  entrada_oprprp

# %%
df_final.to_csv(f'Loja_{loja}/loja_{loja}_tabela_1.csv', encoding='utf-8')
