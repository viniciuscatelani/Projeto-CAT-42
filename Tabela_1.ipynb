# %%
# Importação das bibliotecas necessárias

import pandas as pd
import numpy as np
import glob
import math

# %%
# Leitura do arquivo de entradas-operação própria

file_1 = pd.read_csv("Loja_88/nfe_entrada_oppropr.txt",sep = '\t', header=1, encoding='utf-8')
file_1.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão', 'Número item', 'Código Produto ou Serviço'
# 'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço', 'Valor ICMS Operação'
# 'Valor ICMS Substituição Tributária','', 'Valor Base Cálculo ICMS ST Retido Operação Anterior'
# 'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM'
# 'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)'
# 'Número CNPJ Destinatário (char)'
# Out:
#                                Chave Acesso NFe  Código CFOP (04 Posições)  \
# 0  35161016878675001816550020000014941120605030                       1411
# 1  35161016878675001816550020000014961120689174                       1202
# 2  35161016878675001816550020000014971120692725                       1411
# 3  35161016878675001816550020000014981120726163                       1411
# 4  35161016878675001816550020000015001120749333                       1411
#
#                 Descrição Produto  Número Item Data Emissão Unidade Comercial  \
# 0      Glibenclamida Germ 5mg 30S            1   02/10/2016            UN
# 1        Apar Pressao Gtech Rw450            1   05/10/2016            UN
# 2     Nisulid 100mg Disp.12S Ache            1   05/10/2016            UN
# 3  Carbocisteina Cim Xpe Ad 100ml            1   06/10/2016            UN
# 4   Puran T4 100mcg 28S Sanof/Ave            1   07/10/2016            UN
#
#    Número CNPJ Destinatário  Número CNPJ Emitente  Código NCM Cod UF Emitente  \
# 0                       NaN        16878675001816    30049099              SP
# 1                       NaN        16878675001816    90189092              SP
# 2                       NaN        16878675001816    30049079              SP
# 3                       NaN        16878675001816    30049093              SP
# 4                       NaN        16878675001816    30043981              SP
#
#    ... Valor ICMS  Valor ICMS Substituição Tributária  \
# 0  ...        NaN                                 NaN
# 1  ...      22,66                                 NaN
# 2  ...        NaN                                 NaN
# 3  ...        NaN                                 NaN
# 4  ...        NaN                                 NaN
#
#    Valor ICMS Substituição Tributária Destino  Valor Total NFE do Produto  \
# 0                                         NaN                        5,21
# 1                                         NaN                       125,9
# 2                                         NaN                       39,83
# 3                                         NaN                       12,08
# 4                                         NaN                        9,21
#
#   Valor Total Tributo Valor Desconto Incondicional  \
# 0                1,37                          NaN
# 1               44,82                          NaN
# 2               12,78                          NaN
# 3                3,88                          NaN
# 4                2,96                          NaN
#
#    Valor Desconto Condicional Valor ICMS Substituto  Valor Frete  Valor Seguro
# 0                         NaN                   NaN          NaN           NaN
# 1                         NaN                   NaN          NaN           NaN
# 2                         NaN                   NaN          NaN           NaN
# 3                         NaN                   NaN          NaN           NaN
# 4                         NaN                   NaN          NaN           NaN
#
# [5 rows x 41 columns]

# %%
file_1.columns
# Out:
# Index(['Chave Acesso NFe', 'Código CFOP (04 Posições)', 'Descrição Produto',
#        'Número Item', 'Data Emissão', 'Unidade Comercial',
#        'Número CNPJ Destinatário', 'Número CNPJ Emitente', 'Código NCM',
#        'Cod UF Emitente', 'Cod UF Destinatário',
#        'Documento Fiscal.Número CNPJ Emitente (char)',
#        'Documento Fiscal Produto.Número CNPJ Emitente (char)',
#        'Número CNPJ Destinatário (char)',
#        'Descrição Informações Adicionais Produto (original)',
#        'Descrição Informações Adicionais Produto',
#        'Indicador Tipo Documento Fiscal',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior', 'Código CEST',
#        'Código CEST (char)', 'Código GTIN', 'Código Produto ou Serviço',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Destino', 'Quantidade Comercial',
#        'Quantidade Tributável', 'Valor ICMS FCP ST Retido',
#        'Valor Percentual FCP ST Retido', 'Valor Base Cálculo FCP ST Retido',
#        'Valor ICMS ST Retido Operação Anterior', 'Valor Produto ou Serviço',
#        'Valor ICMS', 'Valor ICMS Substituição Tributária',
#        'Valor ICMS Substituição Tributária Destino',
#        'Valor Total NFE do Produto', 'Valor Total Tributo',
#        'Valor Desconto Incondicional', 'Valor Desconto Condicional',
#        'Valor ICMS Substituto', 'Valor Frete', 'Valor Seguro'],
#       dtype='object')

# %%
# Seleção das colunas necessárias do
# arquivo entradas-operação própria

file_1_new = file_1.copy()
file_1_new = file_1_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item', 'Código Produto ou Serviço',
                    'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                    'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                    'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                    'Unidade Comercial', 'Código NCM',
                    'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)',
                    'Número CNPJ Destinatário (char)']]

file_1_new['Tipo'] = ['entrada_oprprp']*len(file_1_new)

file_1_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161016878675001816550020000014941120605030   02/10/2016            1
# 1  35161016878675001816550020000014961120689174   05/10/2016            1
# 2  35161016878675001816550020000014971120692725   05/10/2016            1
# 3  35161016878675001816550020000014981120726163   06/10/2016            1
# 4  35161016878675001816550020000015001120749333   07/10/2016            1
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    912048                       1411               1,0000
# 1                    929547                       1202               1,0000
# 2                     28142                       1411               1,0000
# 3                    127985                       1411               1,0000
# 4                    928911                       1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS  Valor ICMS Substituição Tributária  \
# 0                     9,48        NaN                                 NaN
# 1                    125,9      22,66                                 NaN
# 2                    44,76        NaN                                 NaN
# 3                    17,27        NaN                                 NaN
# 4                    10,84        NaN                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              19,48
# 1                                                NaN
# 2                                              55,16
# 3                                              48,18
# 4                                              12,75
#
#                 Descrição Produto     Código GTIN Unidade Comercial  \
# 0      Glibenclamida Germ 5mg 30S  7896004707945             UN
# 1        Apar Pressao Gtech Rw450  7898301052834             UN
# 2     Nisulid 100mg Disp.12S Ache  7896658005084             UN
# 3  Carbocisteina Cim Xpe Ad 100ml  7896523207711             UN
# 4   Puran T4 100mcg 28S Sanof/Ave  7891058006402             UN
#
#    Código NCM  Código CEST  Documento Fiscal.Número CNPJ Emitente (char)  \
# 0    30049099    1300200.0                                16878675001816
# 1    90189092          NaN                                16878675001816
# 2    30049079    1300100.0                                16878675001816
# 3    30049093          NaN                                16878675001816
# 4    30043981    1300100.0                                16878675001816
#
#    Número CNPJ Destinatário (char)            Tipo
# 0                              NaN  entrada_oprprp
# 1                              NaN  entrada_oprprp
# 2                              NaN  entrada_oprprp
# 3                              NaN  entrada_oprprp
# 4                              NaN  entrada_oprprp

# %%
# Leitura do arquivo de entradas- outras entradas
# (entradas de outros estados que não SP)

file_2 = pd.read_csv("Loja_88/nfe_entrada_outras.txt", sep='\t', header=1, encoding = 'utf-8')
file_2.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão','Número Item', 'Número CNPJ Emitente (char)',
# 'Número CNPJ Destinatário (char)', 'Código GTIN', 'Código NCM',
# 'Descrição Produto', 'Código CFOP (04 Posições)', 'Unidade Comercial',
# 'Valor Base Cálculo ICMS Substituição Tributária', 'Valor ICMS ST Retido Operação Anterior',
# 'Código Produto ou Serviço', 'Código CEST (char)'
# Out:
#                             Chave Acesso Nota Fiscal  \
# 0  32.180.828.268.233.000.000.000.000.000.000.000...
# 1  32.200.405.607.657.000.000.000.000.000.000.000...
# 2  32.201.223.209.013.000.000.000.000.000.000.000...
# 3  50.190.607.259.917.000.000.000.000.000.000.000...
# 4  50.190.607.259.917.000.000.000.000.000.000.000...
#
#                                Chave Acesso NFe  Referencia Mês Emissão  \
# 0  32180828268233000784550010001348471398557998                 201.808
# 1  32200405607657001026550210001395801007819324                 202.004
# 2  32201223209013000332550010001794601875534164                 202.012
# 3  50190607259917000154550010000036041621616266                 201.906
# 4  50190607259917000154550010000036041621616266                 201.906
#
#   Data Emissão  Indicador Situação Documento Fiscal  \
# 0     1/8/2018                                    0
# 1     6/4/2020                                    0
# 2    7/12/2020                                    0
# 3    30/6/2019                                    0
# 4    30/6/2019                                    0
#
#    Indicador Tipo Documento Fiscal  Número CNPJ Emitente (char)  \
# 0                                1               28268233000784
# 1                                1                5607657001026
# 2                                1               23209013000332
# 3                                1                7259917000154
# 4                                1                7259917000154
#
#    Número CNPJ Destinatário (char)  Número Item  Código NCM  ... Código Barra  \
# 0                   16878675001816            1    85176259  ...          NaN
# 1                   16878675001816            1    84433239  ...          NaN
# 2                   16878675001816            1    84145990  ...          NaN
# 3                   16878675001816            1    85235990  ...          NaN
# 4                   16878675001816            2    85235990  ...          NaN
#
#    Código CEST Código CEST (char) Valor ICMS Operação Valor ICMS Diferido  \
# 0    2105600.0          2105600.0                 NaN                 NaN
# 1    2101700.0          2101700.0                 NaN                 NaN
# 2     103600.0           103600.0                 NaN                 NaN
# 3          NaN                NaN                 NaN                 NaN
# 4          NaN                NaN                 NaN                 NaN
#
#   Valor Desconto Incondicionado  Valor Desconto Condicionado  Valor Outro  \
# 0                           NaN                          NaN          NaN
# 1                           NaN                          NaN          NaN
# 2                           NaN                          NaN          NaN
# 3                           NaN                          NaN          NaN
# 4                           NaN                          NaN          NaN
#
#    Valor Dedução  Quantidade Comercial
# 0            NaN                1,0000
# 1            NaN                1,0000
# 2            NaN                6,0000
# 3            NaN               35,0000
# 4            NaN               45,0000
#
# [5 rows x 48 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-outras entradas

file_2_new = file_2.copy()
file_2_new = file_2_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Tributável','Valor Produto ou Serviço','Valor ICMS Operação',
                         'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                         'Unidade Comercial','Código NCM','Código CEST (char)',
                         'Número CNPJ Emitente (char)','Número CNPJ Destinatário (char)']]

file_2_new['Tipo'] = ['entrada_outras']*len(file_2_new)
file_2_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  32180828268233000784550010001348471398557998     1/8/2018            1
# 1  32200405607657001026550210001395801007819324     6/4/2020            1
# 2  32201223209013000332550010001794601875534164    7/12/2020            1
# 3  50190607259917000154550010000036041621616266    30/6/2019            1
# 4  50190607259917000154550010000036041621616266    30/6/2019            2
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Tributável  \
# 0                    FG-30E                      6.923                1,0000
# 1                    822259                      6.102                1,0000
# 2                    004901                      6.102                6,0000
# 3              010010000000                      6.949               35,0000
# 4              010030000000                      6.949               45,0000
#
#   Valor Produto ou Serviço  Valor ICMS Operação  \
# 0                 1.155,64                  NaN
# 1                      509                  NaN
# 2                    3.834                  NaN
# 3                     33,6                  NaN
# 4                    43,65                  NaN
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Descrição Produto     Código GTIN  \
# 0  5 x GE RJ45 ports (Including 1 x WAN port, 4 x...  SEM GTIN
# 1  C31CH26031_ES EPSON IMPRESSORA TERMICA TM-T20X...  0010343952010
# 2        SPRINGER - CORTINA DE AR ACF12S5 120CM 220V  7898626572178
# 3                                         ONLINE TIM  SEM GTIN
# 4                                       ONLINE CLARO  SEM GTIN
#
#   Unidade Comercial  Código NCM  Código CEST (char)  \
# 0            UN        85176259           2105600.0
# 1            UN        84433239           2101700.0
# 2            PC        84145990            103600.0
# 3            UN        85235990                 NaN
# 4            UN        85235990                 NaN
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)  \
# 0               28268233000784                   16878675001816
# 1                5607657001026                   16878675001816
# 2               23209013000332                   16878675001816
# 3                7259917000154                   16878675001816
# 4                7259917000154                   16878675001816
#
#              Tipo
# 0  entrada_outras
# 1  entrada_outras
# 2  entrada_outras
# 3  entrada_outras
# 4  entrada_outras

# %%
# Leitura do arquivo de entradas- entradas SP
# (entradas de SP)


file_3 = pd.read_csv("Loja_88/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
file_3.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Código CEST', 'Código CFOP (04 Posições)'
# 'Descrição Produto', 'Código Produto ou Serviço', 'Número Item', 'Data Emissão'
# 'Unidade Comercial', 'Número CNPJ Emitente', 'Número CNPJ Destinatário (char)'
# 'Código NCM', 'Código GTIN', 'Quantidade Comercial', 'Valor ICMS ST Retido Operação Anterior'
# 'Valor Produto ou Serviço', 'Valor ICMS Substituição Tributária'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_14652\2272267802.py:5: DtypeWarning: Columns (5,15,16,21,22,31,32,34,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_3 = pd.read_csv("Loja_88/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
#                                Chave Acesso NFe  Código CEST  \
# 0  35161001206820000520550030029922301206101127    1300400.0
# 1  35161001206820000520550030029922301206101127    1300400.0
# 2  35161001206820000520550030029922301206101127    1300400.0
# 3  35161001206820000520550030029922301206101127    1300501.0
# 4  35161001206820000520550030029922301206101127    1700100.0
#
#    Código CEST (char)  Código CFOP (04 Posições)  \
# 0           1300400.0                       5405
# 1           1300400.0                       5405
# 2           1300400.0                       5405
# 3           1300501.0                       5405
# 4           1700100.0                       5102
#
#                     Descrição Produto Código Produto ou Serviço  Número Item  \
# 0             CETROLAC COL 5ML-OUTROS                   0114747            1
# 1       OCTIFEN 0,25MG COL 5ML-OUTROS                   0110988            3
# 2                STILL COL 5ML-OUTROS                   0017655            5
# 3     MOLIERI 30 CPR REV 1X21-SIMILAR                   0115511            2
# 4  REDOXITOS UVA PCT 1X25-DEMAIS PROD                   0122159            4
#
#   Data Emissão Unidade Comercial  Número CNPJ Emitente  ...  Valor ICMS  \
# 0   17/10/2016            FRC            1206820000520  ...         NaN
# 1   17/10/2016            FRC            1206820000520  ...         NaN
# 2   17/10/2016            FRC            1206820000520  ...         NaN
# 3   17/10/2016            BLT            1206820000520  ...         NaN
# 4   17/10/2016            UN             1206820000520  ...        2,54
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Valor ICMS Substituição Tributária Destino Valor Total NFE do Produto  \
# 0                                        NaN                      78,74
# 1                                        NaN                      19,88
# 2                                        NaN                      20,06
# 3                                        NaN                       31,1
# 4                                        NaN                      21,18
#
#   Valor Total Tributo Valor Desconto Incondicional Valor Desconto Condicional  \
# 0                 NaN                          NaN                        NaN
# 1                 NaN                          NaN                        NaN
# 2                 NaN                          NaN                        NaN
# 3                 NaN                          NaN                        NaN
# 4                 NaN                          NaN                        NaN
#
#   Valor ICMS Substituto Valor Frete Valor Seguro
# 0                   NaN         NaN          NaN
# 1                   NaN         NaN          NaN
# 2                   NaN         NaN          NaN
# 3                   NaN         NaN          NaN
# 4                   NaN         NaN          NaN
#
# [5 rows x 40 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-entradas SP

file_3_new = file_3.copy()
file_3_new = file_3_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS', 
                         'Valor ICMS Substituição Tributária','Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior',
                         'Descrição Produto','Código GTIN','Unidade Comercial','Código NCM',
                         'Código CEST','Número CNPJ Emitente', 'Número CNPJ Destinatário (char)']]

file_3_new['Tipo'] = ['entrada_sp']*len(file_3_new)

file_3_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161001206820000520550030029922301206101127   17/10/2016            1
# 1  35161001206820000520550030029922301206101127   17/10/2016            3
# 2  35161001206820000520550030029922301206101127   17/10/2016            5
# 3  35161001206820000520550030029922301206101127   17/10/2016            2
# 4  35161001206820000520550030029922301206101127   17/10/2016            4
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                   0114747                       5405               2,0000
# 1                   0110988                       5405               1,0000
# 2                   0017655                       5405               2,0000
# 3                   0115511                       5405               1,0000
# 4                   0122159                       5102               2,0000
#
#   Valor Produto ou Serviço Valor ICMS Valor ICMS Substituição Tributária  \
# 0                    78,74        NaN                                NaN
# 1                    19,88        NaN                                NaN
# 2                    21,76        NaN                                NaN
# 3                    34,45        NaN                                NaN
# 4                    21,18       2,54                                NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                             100,62
# 1                                              25,41
# 2                                              22,51
# 3                                              35,52
# 4                                                NaN
#
#                     Descrição Produto     Código GTIN Unidade Comercial  \
# 0             CETROLAC COL 5ML-OUTROS  7896006290070             FRC
# 1       OCTIFEN 0,25MG COL 5ML-OUTROS  7896006222620             FRC
# 2                STILL COL 5ML-OUTROS  7897316802335             FRC
# 3     MOLIERI 30 CPR REV 1X21-SIMILAR  7891317498306             BLT
# 4  REDOXITOS UVA PCT 1X25-DEMAIS PROD  4008500018118             UN
#
#    Código NCM  Código CEST  Número CNPJ Emitente  \
# 0    30049072    1300400.0         1206820000520
# 1    30049079    1300400.0         1206820000520
# 2    30049099    1300400.0         1206820000520
# 3    30066000    1300501.0         1206820000520
# 4    17049020    1700100.0         1206820000520
#
#    Número CNPJ Destinatário (char)        Tipo
# 0                   16878675001816  entrada_sp
# 1                   16878675001816  entrada_sp
# 2                   16878675001816  entrada_sp
# 3                   16878675001816  entrada_sp
# 4                   16878675001816  entrada_sp

# %%
# Leitura do arquivo de saídas-dfe

file_4 = pd.read_table('Loja_88/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
file_4.head()

# Colunas a serem usadas:
# 'Descrição Produto', 'Código EAN', 'Código Produto', 'Chave CF-e', 'Unidade Comercial'
# 'Número Item', 'Código CFOP 04 Posições', 'Data Emissao', 'Quantidade Comercial'
# 'Valor Item'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_14652\830590146.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   file_4 = pd.read_table('Loja_88/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
# C:\Users\vinic\AppData\Local\Temp\ipykernel_14652\830590146.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_4 = pd.read_table('Loja_88/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
#           Descrição Produto  Código CEST    Código EAN  Código Produto  \
# 0  0 - BROMOPRIDA PRATI 10M          NaN  7.898148e+12          112342
# 1  0 - BROMOPRIDA PRATI 10M          NaN  7.898148e+12          112342
# 2  0 - BROMOPRIDA PRATI 10M          NaN  7.898148e+12          112342
# 3   0 - DUOMO HP 30S EUROFA          NaN  7.891317e+12           32979
# 4   0 - ESOMEPRAZOL 20MG 28          NaN  7.895296e+12          121269
#
#                                      Chave CF-e Unidade Comercial  \
# 0  35190516878675001816590003377700999941774598                UN
# 1  35190516878675001816590003377700999941774598                UN
# 2  35190516878675001816590003377700999941774598                UN
# 3  35190516878675001816590003377700999941774598                UN
# 4  35190516878675001816590003377700999941774598                UN
#
#    Número Item  Código CFOP 04 Posições Informações Adicicionais  \
# 0            4                     5405                      NaN
# 1            5                     5405                      NaN
# 2            6                     5405                      NaN
# 3            3                     5405                      NaN
# 4            1                     5405                      NaN
#
#         Num Cnpj Emit Data Emissao Valor Produtos Valor Icms  \
# 0  16.878.675/0018-16    5/20/2019          22,04        NaN
# 1  16.878.675/0018-16    5/20/2019          22,04        NaN
# 2  16.878.675/0018-16    5/20/2019          22,04        NaN
# 3  16.878.675/0018-16    5/20/2019         119,28        NaN
# 4  16.878.675/0018-16    5/20/2019         101,61        NaN
#
#   Quantidade Comercial Valor Item Valor Unitário Comercialização  \
# 0               1,0000      11,02                         22,040
# 1               1,0000      11,02                         22,040
# 2               1,0000      11,02                         22,040
# 3               1,0000      89,46                        119,280
# 4               1,0000      50,81                        101,610
#
#   Valor Desconto  Valor Outro  Valor Rateio Desconto  Valor Rateio Acrescimo
# 0          11,02          NaN                    NaN                     NaN
# 1          11,02          NaN                    NaN                     NaN
# 2          11,02          NaN                    NaN                     NaN
# 3          29,82          NaN                    NaN                     NaN
# 4          50,80          NaN                    NaN                     NaN

# %%
# Seleção das colunas necessárias
# do arquivos saídas-dfe

file_4_new = file_4.copy()
file_4_new = file_4_new[['Chave CF-e', 'Data Emissao', 'Número Item',
                        'Código Produto', 'Código CFOP 04 Posições','Valor Icms',
                        'Quantidade Comercial', 'Valor Produtos','Descrição Produto','Código EAN',
                        'Unidade Comercial', 'Código CEST']]

file_4_new['Tipo'] = ['dfe']*len(file_4_new)

file_4_new.head()
# Out:
#                                      Chave CF-e Data Emissao  Número Item  \
# 0  35190516878675001816590003377700999941774598    5/20/2019            4
# 1  35190516878675001816590003377700999941774598    5/20/2019            5
# 2  35190516878675001816590003377700999941774598    5/20/2019            6
# 3  35190516878675001816590003377700999941774598    5/20/2019            3
# 4  35190516878675001816590003377700999941774598    5/20/2019            1
#
#    Código Produto  Código CFOP 04 Posições Valor Icms Quantidade Comercial  \
# 0          112342                     5405        NaN               1,0000
# 1          112342                     5405        NaN               1,0000
# 2          112342                     5405        NaN               1,0000
# 3           32979                     5405        NaN               1,0000
# 4          121269                     5405        NaN               1,0000
#
#   Valor Produtos         Descrição Produto    Código EAN Unidade Comercial  \
# 0          22,04  0 - BROMOPRIDA PRATI 10M  7.898148e+12                UN
# 1          22,04  0 - BROMOPRIDA PRATI 10M  7.898148e+12                UN
# 2          22,04  0 - BROMOPRIDA PRATI 10M  7.898148e+12                UN
# 3         119,28   0 - DUOMO HP 30S EUROFA  7.891317e+12                UN
# 4         101,61   0 - ESOMEPRAZOL 20MG 28  7.895296e+12                UN
#
#    Código CEST Tipo
# 0          NaN  dfe
# 1          NaN  dfe
# 2          NaN  dfe
# 3          NaN  dfe
# 4          NaN  dfe

# %%
# Leitura do arquivo de saídas- nfe saídas

file_5 = pd.read_csv('Loja_88/nfe_saidas.txt', encoding='utf-8', sep='\t', header=1)
file_5.head()

# Colunas a serem usadas:
# 'Data Emissão', 'Chave Acesso NFe', 'Código GTIN', 'Número Item'
# 'Código Produto ou Serviço', 'Descrição Produto', 'Código NCM'
# 'Código CFOP (04 Posições)', 'Unidade Comercial', 'Número CNPJ Destinatário (char)'
# 'Número CNPJ Emitente (char)', 'Quantidade Comercial', 'Valor Produto ou Serviço'
# Out:
#   Data Emissão                              Chave Acesso NFe  Código CEST  \
# 0   01/10/2016  35161016878675001816550020000014931009302958    2801000.0
# 1   05/10/2016  35161016878675001816550020000014951120680692    1300301.0
# 2   05/10/2016  35161016878675001816550020000014951120680692    1301101.0
# 3   05/10/2016  35161016878675001816550020000014951120680692    1301200.0
# 4   05/10/2016  35161016878675001816550020000014951120680692    2006400.0
#
#       Código GTIN  Código CEST (char)  Número Item Código Produto ou Serviço  \
# 0  7893353610421            2801000.0            1                     54692
# 1                           1300301.0            4                    866442
# 2                           1301101.0            7                    921049
# 3                           1301200.0            5                     37499
# 4                           2006400.0            6                    791947
#
#                 Descrição Produto    Descrição Produto (original)  Código NCM  \
# 0             Cicatrimed Gel 30gr             Cicatrimed Gel 30gr    33049990
# 1  Sal De Fruta Tradicional 2 Env  Sal De Fruta Tradicional 2 Env    30049029
# 2  Espar Sanf/Fc/Conl Micr 12x4.5  Espar Sanf/Fc/Conl Micr 12x4.5    30051090
# 3     Luva Cirurgica Sensitex 8,0     Luva Cirurgica Sensitex 8,0    40151100
# 4   Apar Prest Ult Grip Movel C/2   Apar Prest Ult Grip Movel C/2    82121020
#
#    ...  Valor ICMS Substituição Tributária  \
# 0  ...                                 NaN
# 1  ...                                 NaN
# 2  ...                                 NaN
# 3  ...                                 NaN
# 4  ...                                 NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              149,1
# 1                                               1,72
# 2                                               2,29
# 3                                               2,54
# 4                                               7,15
#
#    Valor ICMS ST Retido Operação Anterior Valor Total Tributo  \
# 0                                   10,76                 NaN
# 1                                    0,08                 NaN
# 2                                    0,17                 NaN
# 3                                    0,19                 NaN
# 4                                    0,36                 NaN
#
#   Valor Total NFE do Produto  Valor Outras Despesas Acessórias Valor Dedução  \
# 0                     106,08                               NaN           NaN
# 1                       1,27                               NaN           NaN
# 2                       1,36                               NaN           NaN
# 3                       1,51                               NaN           NaN
# 4                       5,15                               NaN           NaN
#
#   Valor Desconto Incondicional Valor Desconto Condicional
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 32 columns]

# %%
# Seleção das colunas necessárias
# do arquivo saídas - nfe saídas

file_5_new = file_5.copy()
file_5_new = file_5_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item',
                        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
                        'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                        'Descrição Produto','Código GTIN', 'Unidade Comercial',
                        'Código NCM','Código CEST', 'Número CNPJ Emitente (char)',
                        'Número CNPJ Destinatário (char)']]

file_5_new['Tipo'] = ['saida_nfe']*len(file_5_new)

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161016878675001816550020000014931009302958   01/10/2016            1
# 1  35161016878675001816550020000014951120680692   05/10/2016            4
# 2  35161016878675001816550020000014951120680692   05/10/2016            7
# 3  35161016878675001816550020000014951120680692   05/10/2016            5
# 4  35161016878675001816550020000014951120680692   05/10/2016            6
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     54692                       5405               8,0000
# 1                    866442                       5927               1,0000
# 2                    921049                       5927               1,0000
# 3                     37499                       5927               1,0000
# 4                    791947                       5927               1,0000
#
#   Valor Produto ou Serviço Valor ICMS               Descrição Produto  \
# 0                   106,08        NaN             Cicatrimed Gel 30gr
# 1                     1,27        NaN  Sal De Fruta Tradicional 2 Env
# 2                     1,36        NaN  Espar Sanf/Fc/Conl Micr 12x4.5
# 3                     1,51        NaN     Luva Cirurgica Sensitex 8,0
# 4                     5,15        NaN   Apar Prest Ult Grip Movel C/2
#
#       Código GTIN Unidade Comercial  Código NCM  Código CEST  \
# 0  7893353610421             UN        33049990    2801000.0
# 1                            UN        30049029    1300301.0
# 2                            UN        30051090    1301101.0
# 3                            UN        40151100    1301200.0
# 4                            UN        82121020    2006400.0
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)       Tipo
# 0               16878675001816                   16758545000363  saida_nfe
# 1               16878675001816                   16878675001816  saida_nfe
# 2               16878675001816                   16878675001816  saida_nfe
# 3               16878675001816                   16878675001816  saida_nfe
# 4               16878675001816                   16878675001816  saida_nfe

# %%
# Renomeação das colunas do dataframe
# de entradas

file_1_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Documento Fiscal.Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_1_new['Data Emissão'] = pd.to_datetime(file_1_new['Data Emissão'], format='%d/%m/%Y')
file_1_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_2_new.rename(
    columns={'Quantidade Tributável':'Quantidade Comercial',
            'Código CEST (char)':'Código CEST',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_2_new['Data Emissão'] = pd.to_datetime(file_2_new['Data Emissão'], format='%d/%m/%Y')
file_2_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_3_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_3_new['Data Emissão'] = pd.to_datetime(file_3_new['Data Emissão'], format='%d/%m/%Y')
file_3_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_4_new.rename(
    columns={'Chave CF-e':'Chave Acesso NFe',
            'Código Produto':'Código Produto ou Serviço',
            'Data Emissao':'Data Emissão',
             'Valor Icms': 'Valor ICMS Operação',
            'Código CFOP 04 Posições':'Código CFOP (04 Posições)',
            'Valor Produtos':'Valor Produto ou Serviço',
            'Código EAN': 'Código GTIN'}, inplace=True)

file_4_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Valor ICMS Operação', 'Quantidade Comercial',
#        'Valor Produto ou Serviço', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código CEST', 'Tipo'],
#       dtype='object')

# %%
file_4_new['Valor ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_4_new['Código NCM'] = np.nan
file_4_new['Número CNPJ Emitente'] = np.nan
file_4_new['Número CNPJ Destinatário'] = np.nan
file_4_new['Data Emissão'] = pd.to_datetime(file_4_new['Data Emissão'], format='%m/%d/%Y')
file_4_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35190516878675001816590003377700999941774598   2019-05-20            4
# 1  35190516878675001816590003377700999941774598   2019-05-20            5
# 2  35190516878675001816590003377700999941774598   2019-05-20            6
# 3  35190516878675001816590003377700999941774598   2019-05-20            3
# 4  35190516878675001816590003377700999941774598   2019-05-20            1
#
#    Código Produto ou Serviço  Código CFOP (04 Posições) Valor ICMS Operação  \
# 0                     112342                       5405                 NaN
# 1                     112342                       5405                 NaN
# 2                     112342                       5405                 NaN
# 3                      32979                       5405                 NaN
# 4                     121269                       5405                 NaN
#
#   Quantidade Comercial Valor Produto ou Serviço         Descrição Produto  \
# 0               1,0000                    22,04  0 - BROMOPRIDA PRATI 10M
# 1               1,0000                    22,04  0 - BROMOPRIDA PRATI 10M
# 2               1,0000                    22,04  0 - BROMOPRIDA PRATI 10M
# 3               1,0000                   119,28   0 - DUOMO HP 30S EUROFA
# 4               1,0000                   101,61   0 - ESOMEPRAZOL 20MG 28
#
#     Código GTIN Unidade Comercial  Código CEST Tipo  \
# 0  7.898148e+12                UN          NaN  dfe
# 1  7.898148e+12                UN          NaN  dfe
# 2  7.898148e+12                UN          NaN  dfe
# 3  7.891317e+12                UN          NaN  dfe
# 4  7.895296e+12                UN          NaN  dfe
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  Código NCM  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#    Número CNPJ Emitente  Número CNPJ Destinatário
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN

# %%
file_5_new.rename(
    columns={'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_5_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código NCM', 'Código CEST',
#        'Número CNPJ Emitente', 'Número CNPJ Destinatário', 'Tipo'],
#       dtype='object')

# %%
file_5_new['Valor ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_5_new['Data Emissão'] = pd.to_datetime(file_5_new['Data Emissão'], format='%d/%m/%Y')

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161016878675001816550020000014931009302958   2016-10-01            1
# 1  35161016878675001816550020000014951120680692   2016-10-05            4
# 2  35161016878675001816550020000014951120680692   2016-10-05            7
# 3  35161016878675001816550020000014951120680692   2016-10-05            5
# 4  35161016878675001816550020000014951120680692   2016-10-05            6
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     54692                       5405               8,0000
# 1                    866442                       5927               1,0000
# 2                    921049                       5927               1,0000
# 3                     37499                       5927               1,0000
# 4                    791947                       5927               1,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                   106,08                 NaN
# 1                     1,27                 NaN
# 2                     1,36                 NaN
# 3                     1,51                 NaN
# 4                     5,15                 NaN
#
#                 Descrição Produto     Código GTIN Unidade Comercial  \
# 0             Cicatrimed Gel 30gr  7893353610421             UN
# 1  Sal De Fruta Tradicional 2 Env                            UN
# 2  Espar Sanf/Fc/Conl Micr 12x4.5                            UN
# 3     Luva Cirurgica Sensitex 8,0                            UN
# 4   Apar Prest Ult Grip Movel C/2                            UN
#
#    Código NCM  Código CEST  Número CNPJ Emitente  Número CNPJ Destinatário  \
# 0    33049990    2801000.0        16878675001816            16758545000363
# 1    30049029    1300301.0        16878675001816            16878675001816
# 2    30051090    1301101.0        16878675001816            16878675001816
# 3    40151100    1301200.0        16878675001816            16878675001816
# 4    82121020    2006400.0        16878675001816            16878675001816
#
#         Tipo  Valor ICMS Substituição Tributária  \
# 0  saida_nfe                                 NaN
# 1  saida_nfe                                 NaN
# 2  saida_nfe                                 NaN
# 3  saida_nfe                                 NaN
# 4  saida_nfe                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
file_1_new = file_1_new.astype(str)
file_2_new = file_2_new.astype(str)
file_3_new = file_3_new.astype(str)
file_4_new = file_4_new.astype(str)
file_5_new = file_5_new.astype(str)

# %%
df_final[df_final['Tipo'] == 'dfe']['Código GTIN'].unique()
# Out:
# array(['nan', '7891045040426.0', '7896261013490.0', ...,
#        '7891106908894.0', '7891106914154.0', '7891106914178.0'],
#       dtype=object)

# %%
df_final = pd.concat([file_1_new, file_2_new, file_3_new, file_4_new, file_5_new])
df_final.head()
# Out:
#                                Chave Acesso NFe Data Emissão Número Item  \
# 0  35161016878675000410550020000026301120607957   2016-10-03           1
# 1  35161016878675000410550020000026311120609809   2016-10-03           1
# 2  35161016878675000410550020000026321120626875   2016-10-03           1
# 3  35161016878675000410550020000026331120656542   2016-10-04           1
# 4  35161016878675000410550020000026341120667673   2016-10-04           1
#
#   Código Produto ou Serviço Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     81331                      1411               4,0000
# 1                     46920                      1411               1,0000
# 2                     19950                      1411               1,0000
# 3                    755975                      1202               1,0000
# 4                     71142                      1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                    153,4                 nan
# 1                    25,79                 nan
# 2                    12,73                 nan
# 3                    36,41                6,55
# 4                    24,61                 nan
#
#   Valor ICMS Substituição Tributária  \
# 0                                nan
# 1                                nan
# 2                                nan
# 3                                nan
# 4                                nan
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              192,1
# 1                                              19,25
# 2                                               17,9
# 3                                                nan
# 4                                              28,05
#
#               Descrição Produto     Código GTIN Unidade Comercial Código NCM  \
# 0       Leite Nan 2 Comfor 800g  7891000079515             UN       19011010
# 1      Naridrin 12horas Ad 30ml  7896004714578             UN       30043929
# 2       Cr Davene Classico 50gr  7898489511017             UN       33049990
# 3  Leite Ensure Chocolate 400gr  7891158100239             UN       21069090
# 4  Hirudoid Pd 500mg 40g Sankyo  7897411610095             UN       30039099
#
#   Código CEST Número CNPJ Emitente Número CNPJ Destinatário            Tipo
# 0   2804100.0       16878675000410                      nan  entrada_oprprp
# 1   1300301.0       16878675000410                      nan  entrada_oprprp
# 2   2801000.0       16878675000410                      nan  entrada_oprprp
# 3   2804100.0       16878675000410                      nan  entrada_oprprp
# 4   1300301.0       16878675000410                      nan  entrada_oprprp

# %%
df_final.to_csv('Loja_04/loja_60_tabela_1.csv', encoding='utf-8')
