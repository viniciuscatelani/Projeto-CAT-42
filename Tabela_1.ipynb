# %%
# Importação das bibliotecas necessárias

import pandas as pd
import numpy as np
import glob
import math

# %%
# Definição da loja a ser utilizada

loja = 125

# %%
# Leitura do arquivo de entradas-operação própria

file_1 = pd.read_csv(f"Loja_{loja}/nfe_entrada_oppropr.txt",sep = '\t', header=1, encoding='utf-8')
file_1.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão', 'Número item', 'Código Produto ou Serviço'
# 'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço', 'Valor ICMS Operação'
# 'Valor ICMS Substituição Tributária','', 'Valor Base Cálculo ICMS ST Retido Operação Anterior'
# 'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM'
# 'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)'
# 'Número CNPJ Destinatário (char)'
# Out:
#                                Chave Acesso NFe  Código CFOP (04 Posições)  \
# 0  35161071605265000919550020000014871120598054                       1411
# 1  35161071605265000919550020000014881120599317                       1411
# 2  35161071605265000919550020000014891120599373                       1411
# 3  35161071605265000919550020000014901120602367                       1411
# 4  35161071605265000919550020000014911120605207                       1411
#
#                Descrição Produto  Número Item Data Emissão Unidade Comercial  \
# 0    Pediletan Lc Cap 60ml Cimed            1   01/10/2016            UN
# 1       Seki Xarope 120ml Zambom            1   01/10/2016            UN
# 2         Fr Bigfral Plus Xg C/7            1   01/10/2016            UN
# 3  Fr Capricho Sensaty Prem M 10            1   02/10/2016            UN
# 4          Tanderalgin 12S Delta            1   02/10/2016            UN
#
#    Número CNPJ Destinatário  Número CNPJ Emitente  Código NCM Cod UF Emitente  \
# 0                       NaN        71605265000919    30039099              SP
# 1                       NaN        71605265000919    30039099              SP
# 2                       NaN        71605265000919    96190000              SP
# 3                       NaN        71605265000919    96190000              SP
# 4                       NaN        71605265000919    30039099              SP
#
#    ... Valor ICMS  Valor ICMS Substituição Tributária  \
# 0  ...        NaN                                 NaN
# 1  ...        NaN                                 NaN
# 2  ...        NaN                                 NaN
# 3  ...        NaN                                 NaN
# 4  ...        NaN                                 NaN
#
#    Valor ICMS Substituição Tributária Destino  Valor Total NFE do Produto  \
# 0                                         NaN                       11,24
# 1                                         NaN                       23,21
# 2                                         NaN                       21,79
# 3                                         NaN                        19,3
# 4                                         NaN                       10,29
#
#   Valor Total Tributo Valor Desconto Incondicional  \
# 0                3,61                          NaN
# 1                7,45                          NaN
# 2                6,99                          NaN
# 3                6,19                          NaN
# 4                 3,3                          NaN
#
#    Valor Desconto Condicional Valor ICMS Substituto  Valor Frete  Valor Seguro
# 0                         NaN                   NaN          NaN           NaN
# 1                         NaN                   NaN          NaN           NaN
# 2                         NaN                   NaN          NaN           NaN
# 3                         NaN                   NaN          NaN           NaN
# 4                         NaN                   NaN          NaN           NaN
#
# [5 rows x 41 columns]

# %%
file_1.columns
# Out:
# Index(['Chave Acesso NFe', 'Código CFOP (04 Posições)', 'Descrição Produto',
#        'Número Item', 'Data Emissão', 'Unidade Comercial',
#        'Número CNPJ Destinatário', 'Número CNPJ Emitente', 'Código NCM',
#        'Cod UF Emitente', 'Cod UF Destinatário',
#        'Documento Fiscal.Número CNPJ Emitente (char)',
#        'Documento Fiscal Produto.Número CNPJ Emitente (char)',
#        'Número CNPJ Destinatário (char)',
#        'Descrição Informações Adicionais Produto (original)',
#        'Descrição Informações Adicionais Produto',
#        'Indicador Tipo Documento Fiscal',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior', 'Código CEST',
#        'Código CEST (char)', 'Código GTIN', 'Código Produto ou Serviço',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Destino', 'Quantidade Comercial',
#        'Quantidade Tributável', 'Valor ICMS FCP ST Retido',
#        'Valor Percentual FCP ST Retido', 'Valor Base Cálculo FCP ST Retido',
#        'Valor ICMS ST Retido Operação Anterior', 'Valor Produto ou Serviço',
#        'Valor ICMS', 'Valor ICMS Substituição Tributária',
#        'Valor ICMS Substituição Tributária Destino',
#        'Valor Total NFE do Produto', 'Valor Total Tributo',
#        'Valor Desconto Incondicional', 'Valor Desconto Condicional',
#        'Valor ICMS Substituto', 'Valor Frete', 'Valor Seguro'],
#       dtype='object')

# %%
# Seleção das colunas necessárias do
# arquivo entradas-operação própria

file_1_new = file_1.copy()
file_1_new = file_1_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item', 'Código Produto ou Serviço',
                    'Código CFOP (04 Posições)', 'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                    'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                    'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                    'Unidade Comercial', 'Código NCM',
                    'Código CEST', 'Documento Fiscal.Número CNPJ Emitente (char)',
                    'Número CNPJ Destinatário (char)']]

file_1_new['Tipo'] = ['entrada_oprprp']*len(file_1_new)

file_1_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161071605265000919550020000014871120598054   01/10/2016            1
# 1  35161071605265000919550020000014881120599317   01/10/2016            1
# 2  35161071605265000919550020000014891120599373   01/10/2016            1
# 3  35161071605265000919550020000014901120602367   02/10/2016            1
# 4  35161071605265000919550020000014911120605207   02/10/2016            1
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    824219                       1411               1,0000
# 1                     77875                       1411               1,0000
# 2                    840272                       1411               1,0000
# 3                     60046                       1411               1,0000
# 4                    817478                       1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS  Valor ICMS Substituição Tributária  \
# 0                    13,02        NaN                                 NaN
# 1                    29,02        NaN                                 NaN
# 2                    21,79        NaN                                 NaN
# 3                     19,3        NaN                                 NaN
# 4                    17,15        NaN                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              15,25
# 1                                              31,12
# 2                                              31,54
# 3                                              27,93
# 4                                              13,97
#
#                Descrição Produto     Código GTIN Unidade Comercial  \
# 0    Pediletan Lc Cap 60ml Cimed  7896523209364             UN
# 1       Seki Xarope 120ml Zambom  7898074618183             UN
# 2         Fr Bigfral Plus Xg C/7  7896012800843             UN
# 3  Fr Capricho Sensaty Prem M 10  7891522021122             UN
# 4          Tanderalgin 12S Delta  7893454209913             UN
#
#    Código NCM  Código CEST  Documento Fiscal.Número CNPJ Emitente (char)  \
# 0    30039099    1300301.0                                71605265000919
# 1    30039099    1300101.0                                71605265000919
# 2    96190000    2005000.0                                71605265000919
# 3    96190000    2005000.0                                71605265000919
# 4    30039099    1300301.0                                71605265000919
#
#    Número CNPJ Destinatário (char)            Tipo
# 0                              NaN  entrada_oprprp
# 1                              NaN  entrada_oprprp
# 2                              NaN  entrada_oprprp
# 3                              NaN  entrada_oprprp
# 4                              NaN  entrada_oprprp

# %%
# Leitura do arquivo de entradas- outras entradas
# (entradas de outros estados que não SP)

file_2 = pd.read_csv(f"Loja_{loja}/nfe_entrada_outras.txt", sep='\t', header=1, encoding = 'utf-8')
file_2.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Data Emissão','Número Item', 'Número CNPJ Emitente (char)',
# 'Número CNPJ Destinatário (char)', 'Código GTIN', 'Código NCM',
# 'Descrição Produto', 'Código CFOP (04 Posições)', 'Unidade Comercial',
# 'Valor Base Cálculo ICMS Substituição Tributária', 'Valor ICMS ST Retido Operação Anterior',
# 'Código Produto ou Serviço', 'Código CEST (char)'
# Out:
#                             Chave Acesso Nota Fiscal  \
# 0  32.180.728.268.233.000.000.000.000.000.000.000...
# 1  32.200.308.824.171.000.000.000.000.000.000.000...
# 2  32.200.308.824.171.000.000.000.000.000.000.000...
# 3  50.190.607.259.917.000.000.000.000.000.000.000...
# 4  50.190.607.259.917.000.000.000.000.000.000.000...
#
#                                Chave Acesso NFe  Referencia Mês Emissão  \
# 0  32180728268233000784550010001345391564234659                 201.807
# 1  32200308824171000570550010002555981117791810                 202.003
# 2  32200308824171000570550010002555981117791810                 202.003
# 3  50190607259917000154550010000039251306329244                 201.906
# 4  50190607259917000154550010000039251306329244                 201.906
#
#   Data Emissão  Indicador Situação Documento Fiscal  \
# 0    25/7/2018                                    0
# 1    27/3/2020                                    0
# 2    27/3/2020                                    0
# 3    30/6/2019                                    0
# 4    30/6/2019                                    0
#
#    Indicador Tipo Documento Fiscal  Número CNPJ Emitente (char)  \
# 0                                1               28268233000784
# 1                                1                8824171000570
# 2                                1                8824171000570
# 3                                1                7259917000154
# 4                                1                7259917000154
#
#    Número CNPJ Destinatário (char)  Número Item  Código NCM  ... Código Barra  \
# 0                   71605265000919            1    85176259  ...          NaN
# 1                   71605265000919            1    84143019  ...          NaN
# 2                   71605265000919            2    29037100  ...          NaN
# 3                   71605265000919            1    85235990  ...          NaN
# 4                   71605265000919            2    85235990  ...          NaN
#
#    Código CEST Código CEST (char) Valor ICMS Operação Valor ICMS Diferido  \
# 0    2105600.0          2105600.0                 NaN                 NaN
# 1          NaN                NaN                 NaN                 NaN
# 2    2804300.0          2804300.0                 NaN                 NaN
# 3          NaN                NaN                 NaN                 NaN
# 4          NaN                NaN                 NaN                 NaN
#
#   Valor Desconto Incondicionado  Valor Desconto Condicionado  Valor Outro  \
# 0                           NaN                          NaN          NaN
# 1                           NaN                          NaN          NaN
# 2                           NaN                          NaN          NaN
# 3                           NaN                          NaN          NaN
# 4                           NaN                          NaN          NaN
#
#    Valor Dedução  Quantidade Comercial
# 0            NaN                1,0000
# 1            NaN                1,0000
# 2            NaN                1,0000
# 3            NaN              155,0000
# 4            NaN              145,0000
#
# [5 rows x 48 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-outras entradas

file_2_new = file_2.copy()
file_2_new = file_2_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Tributável','Valor Produto ou Serviço','Valor ICMS Operação',
                         'Valor ICMS Substituição Tributária', 'Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior','Descrição Produto', 'Código GTIN',
                         'Unidade Comercial','Código NCM','Código CEST (char)',
                         'Número CNPJ Emitente (char)','Número CNPJ Destinatário (char)']]

file_2_new['Tipo'] = ['entrada_outras']*len(file_2_new)
file_2_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  32180728268233000784550010001345391564234659    25/7/2018            1
# 1  32200308824171000570550010002555981117791810    27/3/2020            1
# 2  32200308824171000570550010002555981117791810    27/3/2020            2
# 3  50190607259917000154550010000039251306329244    30/6/2019            1
# 4  50190607259917000154550010000039251306329244    30/6/2019            2
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Tributável  \
# 0                    FG-30E                      6.923                1,0000
# 1                      7398                      6.102                1,0000
# 2                         5                      6.102                1,0000
# 3              010010000000                      6.949              155,0000
# 4              010050000000                      6.949              145,0000
#
#   Valor Produto ou Serviço  Valor ICMS Operação  \
# 0                 1.155,63                  NaN
# 1                    1.390                  NaN
# 2                      480                  NaN
# 3                    148,8                  NaN
# 4                   140,65                  NaN
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Descrição Produto     Código GTIN  \
# 0  5 x GE RJ45 ports (Including 1 x WAN port, 4 x...  SEM GTIN
# 1           COMP SCROL SANYO 5TR 220/3 CSB353H6B R22  SEM GTIN
# 2           GAS DUPONT FREON R-22 DAC 13,62 KG(3102)  0686114000473
# 3                                         ONLINE TIM  SEM GTIN
# 4                                          ONLINE OI  SEM GTIN
#
#   Unidade Comercial  Código NCM  Código CEST (char)  \
# 0            UN        85176259           2105600.0
# 1            UN        84143019                 NaN
# 2            UN        29037100           2804300.0
# 3            UN        85235990                 NaN
# 4            UN        85235990                 NaN
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)  \
# 0               28268233000784                   71605265000919
# 1                8824171000570                   71605265000919
# 2                8824171000570                   71605265000919
# 3                7259917000154                   71605265000919
# 4                7259917000154                   71605265000919
#
#              Tipo
# 0  entrada_outras
# 1  entrada_outras
# 2  entrada_outras
# 3  entrada_outras
# 4  entrada_outras

# %%
# Leitura do arquivo de entradas- entradas SP
# (entradas de SP)


file_3 = pd.read_csv(f"Loja_{loja}/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
file_3.head()

# Colunas a serem usadas:
# 'Chave Acesso NFe', 'Código CEST', 'Código CFOP (04 Posições)'
# 'Descrição Produto', 'Código Produto ou Serviço', 'Número Item', 'Data Emissão'
# 'Unidade Comercial', 'Número CNPJ Emitente', 'Número CNPJ Destinatário (char)'
# 'Código NCM', 'Código GTIN', 'Quantidade Comercial', 'Valor ICMS ST Retido Operação Anterior'
# 'Valor Produto ou Serviço', 'Valor ICMS Substituição Tributária'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_23372\369719733.py:5: DtypeWarning: Columns (5,15,16,21,22,31,32,34,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_3 = pd.read_csv(f"Loja_{loja}/nfe_entrada_sp.txt", sep='\t', header=1, encoding = 'utf-8')
#                                Chave Acesso NFe  Código CEST  \
# 0  35161001206820000520550030029861791261213969    1300400.0
# 1  35161001206820000520550030029861791261213969    1300401.0
# 2  35161001206820000520550030029861791261213969    1300401.0
# 3  35161001206820000520550030029937091375443953    1300401.0
# 4  35161001206820000520550030029937091375443953    1300401.0
#
#    Código CEST (char)  Código CFOP (04 Posições)  \
# 0           1300400.0                       5405
# 1           1300401.0                       5405
# 2           1300401.0                       5405
# 3           1300401.0                       5405
# 4           1300401.0                       5405
#
#               Descrição Produto Código Produto ou Serviço  Número Item  \
# 0          STILL COL 5ML-OUTROS                     17655            3
# 1     BROMELIN XPE 100ML-OUTROS                     98491            1
# 2    FACYL 500MG CPR 1X8-OUTROS                     12556            2
# 3  ANDRIODERMOL LIQ 50ML-OUTROS                     25283            1
# 4           VODOL CR 28G-OUTROS                     25640            2
#
#   Data Emissão Unidade Comercial  Número CNPJ Emitente  ...  Valor ICMS  \
# 0   15/10/2016            FRC            1206820000520  ...         NaN
# 1   15/10/2016            VD             1206820000520  ...         NaN
# 2   15/10/2016            CX             1206820000520  ...         NaN
# 3   18/10/2016            VD             1206820000520  ...         NaN
# 4   18/10/2016            TB             1206820000520  ...         NaN
#
#    Valor ICMS Substituição Tributária  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Valor ICMS Substituição Tributária Destino Valor Total NFE do Produto  \
# 0                                        NaN                      10,03
# 1                                        NaN                      33,15
# 2                                        NaN                      14,59
# 3                                        NaN                       25,9
# 4                                        NaN                      32,56
#
#   Valor Total Tributo Valor Desconto Incondicional Valor Desconto Condicional  \
# 0                 NaN                          NaN                        NaN
# 1                 NaN                          NaN                        NaN
# 2                 NaN                          NaN                        NaN
# 3                 NaN                          NaN                        NaN
# 4                 NaN                          NaN                        NaN
#
#   Valor ICMS Substituto Valor Frete Valor Seguro
# 0                   NaN         NaN          NaN
# 1                   NaN         NaN          NaN
# 2                   NaN         NaN          NaN
# 3                   NaN         NaN          NaN
# 4                   NaN         NaN          NaN
#
# [5 rows x 40 columns]

# %%
# Seleção das colunas necessárias do
# arquivo entradas-entradas SP

file_3_new = file_3.copy()
file_3_new = file_3_new[['Chave Acesso NFe', 'Data Emissão','Número Item','Código Produto ou Serviço',
                         'Código CFOP (04 Posições)','Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS', 
                         'Valor ICMS Substituição Tributária','Valor Base Cálculo ICMS Substituição Tributária',
                         'Valor Base Cálculo ICMS ST Retido Operação Anterior',
                         'Descrição Produto','Código GTIN','Unidade Comercial','Código NCM',
                         'Código CEST','Número CNPJ Emitente', 'Número CNPJ Destinatário (char)']]

file_3_new['Tipo'] = ['entrada_sp']*len(file_3_new)

file_3_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161001206820000520550030029861791261213969   15/10/2016            3
# 1  35161001206820000520550030029861791261213969   15/10/2016            1
# 2  35161001206820000520550030029861791261213969   15/10/2016            2
# 3  35161001206820000520550030029937091375443953   18/10/2016            1
# 4  35161001206820000520550030029937091375443953   18/10/2016            2
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                     17655                       5405               1,0000
# 1                     98491                       5405               1,0000
# 2                     12556                       5405               1,0000
# 3                     25283                       5405               2,0000
# 4                     25640                       5405               2,0000
#
#   Valor Produto ou Serviço Valor ICMS Valor ICMS Substituição Tributária  \
# 0                    10,88        NaN                                NaN
# 1                    37,42        NaN                                NaN
# 2                    15,33        NaN                                NaN
# 3                     25,9        NaN                                NaN
# 4                    32,56        NaN                                NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              11,26
# 1                                              41,58
# 2                                              17,24
# 3                                              29,39
# 4                                              36,94
#
#               Descrição Produto     Código GTIN Unidade Comercial  Código NCM  \
# 0          STILL COL 5ML-OUTROS  7897316802335             FRC       30049099
# 1     BROMELIN XPE 100ML-OUTROS  7896685300473             VD        30049019
# 2    FACYL 500MG CPR 1X8-OUTROS  7896422505895             CX        30049099
# 3  ANDRIODERMOL LIQ 50ML-OUTROS  7896006214007             VD        30049029
# 4           VODOL CR 28G-OUTROS  7896006292005             TB        30049066
#
#    Código CEST  Número CNPJ Emitente  Número CNPJ Destinatário (char)  \
# 0    1300400.0         1206820000520                   71605265000919
# 1    1300401.0         1206820000520                   71605265000919
# 2    1300401.0         1206820000520                   71605265000919
# 3    1300401.0         1206820000520                   71605265000919
# 4    1300401.0         1206820000520                   71605265000919
#
#          Tipo
# 0  entrada_sp
# 1  entrada_sp
# 2  entrada_sp
# 3  entrada_sp
# 4  entrada_sp

# %%
# Leitura do arquivo de saídas-dfe

file_4 = pd.read_table(f'Loja_{loja}/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
#file_4_2 = pd.read_table('Loja_26/dfe2.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)

#file_4 = pd.concat([file_4_1, file_4_2])
file_4.head()

# Colunas a serem usadas:
# 'Descrição Produto', 'Código EAN', 'Código Produto', 'Chave CF-e', 'Unidade Comercial'
# 'Número Item', 'Código CFOP 04 Posições', 'Data Emissao', 'Quantidade Comercial'
# 'Valor Item'
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_23372\2709034502.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   file_4 = pd.read_table(f'Loja_{loja}/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
# C:\Users\vinic\AppData\Local\Temp\ipykernel_23372\2709034502.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_4 = pd.read_table(f'Loja_{loja}/dfe.txt', encoding='utf-8', header=1, quoting=3, error_bad_lines=False)
#                       Descrição Produto  Código CEST    Código EAN  \
# 0         100% PURE WHEY 900G CHOCOLATE          NaN           NaN
# 1     107 - DES MONANGE A 90G INVISIVEL          NaN  7.898919e+12
# 2           1118 - ALOPURINOL MEDLEY 10          NaN  7.896423e+12
# 3  1118 - LEVONORGESTREL 1,5MG 1'S MELC          NaN  7.898907e+12
# 4          11295 - AAS CIMED 100MG 30'S          NaN  7.896523e+12
#
#    Código Produto                                    Chave CF-e  \
# 0          163360  35171071605265000919590003391080001546433758
# 1          177360  35190471605265000919590003511470933537706731
# 2          907105  35200671605265000919590007961470297755729182
# 3          126359  35190971605265000919590003511471146878387789
# 4          186601  35190971605265000919590003391081183010402993
#
#   Unidade Comercial  Número Item  Código CFOP 04 Posições  \
# 0                UN            1                     5102
# 1                UN            1                     5405
# 2                UN            1                     5405
# 3                UN            1                     5405
# 4                UN            3                     5405
#
#   Informações Adicicionais       Num Cnpj Emit Data Emissao Valor Produtos  \
# 0   De: 158.58 Por: 108.19  71.605.265/0009-19    10/7/2017         158,58
# 1                      NaN  71.605.265/0009-19    4/20/2019           7,19
# 2                      NaN  71.605.265/0009-19    6/19/2020          10,37
# 3                      NaN  71.605.265/0009-19    9/14/2019          20,68
# 4                      NaN  71.605.265/0009-19    9/21/2019           7,57
#
#   Valor Icms Quantidade Comercial Valor Item Valor Unitário Comercialização  \
# 0      19,47               1,0000     108,19                        158,580
# 1        NaN               1,0000       7,19                          7,190
# 2        NaN               1,0000       7,36                         10,370
# 3        NaN               1,0000      12,82                         20,680
# 4        NaN               1,0000       3,94                          7,570
#
#   Valor Desconto  Valor Outro  Valor Rateio Desconto  Valor Rateio Acrescimo
# 0          50,39          NaN                    NaN                     NaN
# 1            NaN          NaN                    NaN                     NaN
# 2           3,01          NaN                    NaN                     NaN
# 3           7,86          NaN                    NaN                     NaN
# 4           3,63          NaN                    NaN                     NaN

# %%
# Seleção das colunas necessárias
# do arquivos saídas-dfe

file_4_new = file_4.copy()
file_4_new = file_4_new[['Chave CF-e', 'Data Emissao', 'Número Item',
                        'Código Produto', 'Código CFOP 04 Posições','Valor Icms',
                        'Quantidade Comercial', 'Valor Item','Descrição Produto','Código EAN',
                        'Unidade Comercial', 'Código CEST']]

file_4_new['Tipo'] = ['dfe']*len(file_4_new)

file_4_new.head()
# Out:
#                                      Chave CF-e Data Emissao  Número Item  \
# 0  35171071605265000919590003391080001546433758    10/7/2017            1
# 1  35190471605265000919590003511470933537706731    4/20/2019            1
# 2  35200671605265000919590007961470297755729182    6/19/2020            1
# 3  35190971605265000919590003511471146878387789    9/14/2019            1
# 4  35190971605265000919590003391081183010402993    9/21/2019            3
#
#    Código Produto  Código CFOP 04 Posições Valor Icms Quantidade Comercial  \
# 0          163360                     5102      19,47               1,0000
# 1          177360                     5405        NaN               1,0000
# 2          907105                     5405        NaN               1,0000
# 3          126359                     5405        NaN               1,0000
# 4          186601                     5405        NaN               1,0000
#
#   Valor Item                     Descrição Produto    Código EAN  \
# 0     108,19         100% PURE WHEY 900G CHOCOLATE           NaN
# 1       7,19     107 - DES MONANGE A 90G INVISIVEL  7.898919e+12
# 2       7,36           1118 - ALOPURINOL MEDLEY 10  7.896423e+12
# 3      12,82  1118 - LEVONORGESTREL 1,5MG 1'S MELC  7.898907e+12
# 4       3,94          11295 - AAS CIMED 100MG 30'S  7.896523e+12
#
#   Unidade Comercial  Código CEST Tipo
# 0                UN          NaN  dfe
# 1                UN          NaN  dfe
# 2                UN          NaN  dfe
# 3                UN          NaN  dfe
# 4                UN          NaN  dfe

# %%
# Leitura do arquivo de saídas- nfe saídas

file_5 = pd.read_csv(f'Loja_{loja}/nfe_saidas.txt', encoding='utf-8', sep='\t', header=1)
file_5.head()

# Colunas a serem usadas:
# 'Data Emissão', 'Chave Acesso NFe', 'Código GTIN', 'Número Item'
# 'Código Produto ou Serviço', 'Descrição Produto', 'Código NCM'
# 'Código CFOP (04 Posições)', 'Unidade Comercial', 'Número CNPJ Destinatário (char)'
# 'Número CNPJ Emitente (char)', 'Quantidade Comercial', 'Valor Produto ou Serviço'
# Out:
#   Data Emissão                              Chave Acesso NFe  Código CEST  \
# 0   04/10/2016  35161071605265000919550020000014951120662722    1300200.0
# 1   04/10/2016  35161071605265000919550020000014951120662722          NaN
# 2   05/10/2016  35161071605265000919550020000014961120683042    2801600.0
# 3   11/10/2016  35161071605265000919550020000015111120839253    2000600.0
# 4   20/10/2016  35161071605265000919550020000015271121082890    1300100.0
#
#       Código GTIN  Código CEST (char)  Número Item Código Produto ou Serviço  \
# 0  7891317451035            1300200.0            1                    885145
# 1  7898301057310                  NaN            2                     99473
# 2  7896094904217            2801600.0            1                    151399
# 3  7898623351202            2000600.0            1                    155341
# 4  7891158000942            1300100.0            7                        18
#
#                 Descrição Produto    Descrição Produto (original)  Código NCM  \
# 0   Atenolol+Cl Euro 50/12.5mg 30   Atenolol+Cl Euro 50/12.5mg 30    30049076
# 1  Apar Pressao Gtech Mast Bp3bk1  Apar Pressao Gtech Mast Bp3bk1    90189092
# 2            MELHORAL C 25X4 COMP            MELHORAL C 25X4 COMP    30049099
# 3     OLEO CORPORAL 120ML LE BLUE     OLEO CORPORAL 120ML LE BLUE    33019010
# 4       Depakene 250mg 25S Abb C1       Depakene 250mg 25S Abb C1    30049099
#
#    ...  Valor ICMS Substituição Tributária  \
# 0  ...                                 NaN
# 1  ...                                 NaN
# 2  ...                                 NaN
# 3  ...                                 NaN
# 4  ...                                 NaN
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              55,05
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              94,66
#
#    Valor ICMS ST Retido Operação Anterior Valor Total Tributo  \
# 0                                    4,84                4,72
# 1                                     NaN               42,36
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                    4,74                  18
#
#   Valor Total NFE do Produto  Valor Outras Despesas Acessórias Valor Dedução  \
# 0                      14,72                               NaN           NaN
# 1                     118,99                               NaN           NaN
# 2                     105,34                               NaN           NaN
# 3                      30,03                               NaN           NaN
# 4                      68,36                               NaN           NaN
#
#   Valor Desconto Incondicional Valor Desconto Condicional
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
# [5 rows x 32 columns]

# %%
# Seleção das colunas necessárias
# do arquivo saídas - nfe saídas

file_5_new = file_5.copy()
file_5_new = file_5_new[['Chave Acesso NFe', 'Data Emissão', 'Número Item',
                        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
                        'Quantidade Comercial', 'Valor Produto ou Serviço','Valor ICMS',
                        'Descrição Produto','Código GTIN', 'Unidade Comercial',
                        'Código NCM','Código CEST', 'Número CNPJ Emitente (char)',
                        'Número CNPJ Destinatário (char)']]

file_5_new['Tipo'] = ['saida_nfe']*len(file_5_new)

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161071605265000919550020000014951120662722   04/10/2016            1
# 1  35161071605265000919550020000014951120662722   04/10/2016            2
# 2  35161071605265000919550020000014961120683042   05/10/2016            1
# 3  35161071605265000919550020000015111120839253   11/10/2016            1
# 4  35161071605265000919550020000015271121082890   20/10/2016            7
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    885145                       5929               1,0000
# 1                     99473                       5929               1,0000
# 2                    151399                       5411               1,0000
# 3                    155341                       5411               7,0000
# 4                        18                       5929               4,0000
#
#   Valor Produto ou Serviço Valor ICMS               Descrição Produto  \
# 0                    24,54        NaN   Atenolol+Cl Euro 50/12.5mg 30
# 1                   118,99      21,42  Apar Pressao Gtech Mast Bp3bk1
# 2                   112,92        NaN            MELHORAL C 25X4 COMP
# 3                    30,03        NaN     OLEO CORPORAL 120ML LE BLUE
# 4                     85,6        NaN       Depakene 250mg 25S Abb C1
#
#       Código GTIN Unidade Comercial  Código NCM  Código CEST  \
# 0  7891317451035             UN        30049076    1300200.0
# 1  7898301057310             UN        90189092          NaN
# 2  7896094904217             CX        30049099    2801600.0
# 3  7898623351202             UN        33019010    2000600.0
# 4  7891158000942             UN        30049099    1300100.0
#
#    Número CNPJ Emitente (char)  Número CNPJ Destinatário (char)       Tipo
# 0               71605265000919                              NaN  saida_nfe
# 1               71605265000919                              NaN  saida_nfe
# 2               71605265000919                     6.194029e+13  saida_nfe
# 3               71605265000919                     1.896634e+13  saida_nfe
# 4               71605265000919                     5.738631e+13  saida_nfe

# %%
# Renomeação das colunas do dataframe
# de entradas

file_1_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Documento Fiscal.Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_1_new['Data Emissão'] = pd.to_datetime(file_1_new['Data Emissão'], format='%d/%m/%Y')
file_1_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_2_new.rename(
    columns={'Quantidade Tributável':'Quantidade Comercial',
            'Código CEST (char)':'Código CEST',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_2_new['Data Emissão'] = pd.to_datetime(file_2_new['Data Emissão'], format='%d/%m/%Y')
file_2_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_3_new.rename(
    columns={'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário',
            'Valor ICMS': 'Valor ICMS Operação'}, inplace=True)

file_3_new['Data Emissão'] = pd.to_datetime(file_3_new['Data Emissão'], format='%d/%m/%Y')
file_3_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Valor ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS Substituição Tributária',
#        'Valor Base Cálculo ICMS ST Retido Operação Anterior',
#        'Descrição Produto', 'Código GTIN', 'Unidade Comercial', 'Código NCM',
#        'Código CEST', 'Número CNPJ Emitente', 'Número CNPJ Destinatário',
#        'Tipo'],
#       dtype='object')

# %%
file_4_new.rename(
    columns={'Chave CF-e':'Chave Acesso NFe',
            'Código Produto':'Código Produto ou Serviço',
            'Data Emissao':'Data Emissão',
             'Valor Icms': 'Valor ICMS Operação',
            'Código CFOP 04 Posições':'Código CFOP (04 Posições)',
            'Valor Item':'Valor Produto ou Serviço',
            'Código EAN': 'Código GTIN'}, inplace=True)

file_4_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Valor ICMS Operação', 'Quantidade Comercial',
#        'Valor Produto ou Serviço', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código CEST', 'Tipo'],
#       dtype='object')

# %%
file_4_new['Valor ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_4_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_4_new['Código NCM'] = np.nan
file_4_new['Número CNPJ Emitente'] = np.nan
file_4_new['Número CNPJ Destinatário'] = np.nan
file_4_new['Data Emissão'] = pd.to_datetime(file_4_new['Data Emissão'], format='%m/%d/%Y')
file_4_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35171071605265000919590003391080001546433758   2017-10-07            1
# 1  35190471605265000919590003511470933537706731   2019-04-20            1
# 2  35200671605265000919590007961470297755729182   2020-06-19            1
# 3  35190971605265000919590003511471146878387789   2019-09-14            1
# 4  35190971605265000919590003391081183010402993   2019-09-21            3
#
#    Código Produto ou Serviço  Código CFOP (04 Posições) Valor ICMS Operação  \
# 0                     163360                       5102               19,47
# 1                     177360                       5405                 NaN
# 2                     907105                       5405                 NaN
# 3                     126359                       5405                 NaN
# 4                     186601                       5405                 NaN
#
#   Quantidade Comercial Valor Produto ou Serviço  \
# 0               1,0000                   108,19
# 1               1,0000                     7,19
# 2               1,0000                     7,36
# 3               1,0000                    12,82
# 4               1,0000                     3,94
#
#                       Descrição Produto   Código GTIN Unidade Comercial  \
# 0         100% PURE WHEY 900G CHOCOLATE           NaN                UN
# 1     107 - DES MONANGE A 90G INVISIVEL  7.898919e+12                UN
# 2           1118 - ALOPURINOL MEDLEY 10  7.896423e+12                UN
# 3  1118 - LEVONORGESTREL 1,5MG 1'S MELC  7.898907e+12                UN
# 4          11295 - AAS CIMED 100MG 30'S  7.896523e+12                UN
#
#    Código CEST Tipo  Valor ICMS Substituição Tributária  \
# 0          NaN  dfe                                 NaN
# 1          NaN  dfe                                 NaN
# 2          NaN  dfe                                 NaN
# 3          NaN  dfe                                 NaN
# 4          NaN  dfe                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior  Código NCM  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#    Número CNPJ Emitente  Número CNPJ Destinatário
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN

# %%
file_5_new.rename(
    columns={'Número CNPJ Emitente (char)':'Número CNPJ Emitente',
             'Valor ICMS': 'Valor ICMS Operação',
            'Número CNPJ Destinatário (char)':'Número CNPJ Destinatário'}, inplace=True)

file_5_new.columns
# Out:
# Index(['Chave Acesso NFe', 'Data Emissão', 'Número Item',
#        'Código Produto ou Serviço', 'Código CFOP (04 Posições)',
#        'Quantidade Comercial', 'Valor Produto ou Serviço',
#        'Valor ICMS Operação', 'Descrição Produto', 'Código GTIN',
#        'Unidade Comercial', 'Código NCM', 'Código CEST',
#        'Número CNPJ Emitente', 'Número CNPJ Destinatário', 'Tipo'],
#       dtype='object')

# %%
file_5_new['Valor ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS Substituição Tributária'] = np.nan
file_5_new['Valor Base Cálculo ICMS ST Retido Operação Anterior'] = np.nan
file_5_new['Data Emissão'] = pd.to_datetime(file_5_new['Data Emissão'], format='%d/%m/%Y')

file_5_new.head()
# Out:
#                                Chave Acesso NFe Data Emissão  Número Item  \
# 0  35161071605265000919550020000014951120662722   2016-10-04            1
# 1  35161071605265000919550020000014951120662722   2016-10-04            2
# 2  35161071605265000919550020000014961120683042   2016-10-05            1
# 3  35161071605265000919550020000015111120839253   2016-10-11            1
# 4  35161071605265000919550020000015271121082890   2016-10-20            7
#
#   Código Produto ou Serviço  Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    885145                       5929               1,0000
# 1                     99473                       5929               1,0000
# 2                    151399                       5411               1,0000
# 3                    155341                       5411               7,0000
# 4                        18                       5929               4,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                    24,54                 NaN
# 1                   118,99               21,42
# 2                   112,92                 NaN
# 3                    30,03                 NaN
# 4                     85,6                 NaN
#
#                 Descrição Produto     Código GTIN Unidade Comercial  \
# 0   Atenolol+Cl Euro 50/12.5mg 30  7891317451035             UN
# 1  Apar Pressao Gtech Mast Bp3bk1  7898301057310             UN
# 2            MELHORAL C 25X4 COMP  7896094904217             CX
# 3     OLEO CORPORAL 120ML LE BLUE  7898623351202             UN
# 4       Depakene 250mg 25S Abb C1  7891158000942             UN
#
#    Código NCM  Código CEST  Número CNPJ Emitente  Número CNPJ Destinatário  \
# 0    30049076    1300200.0        71605265000919                       NaN
# 1    90189092          NaN        71605265000919                       NaN
# 2    30049099    2801600.0        71605265000919              6.194029e+13
# 3    33019010    2000600.0        71605265000919              1.896634e+13
# 4    30049099    1300100.0        71605265000919              5.738631e+13
#
#         Tipo  Valor ICMS Substituição Tributária  \
# 0  saida_nfe                                 NaN
# 1  saida_nfe                                 NaN
# 2  saida_nfe                                 NaN
# 3  saida_nfe                                 NaN
# 4  saida_nfe                                 NaN
#
#    Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Valor Base Cálculo ICMS ST Retido Operação Anterior
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
file_1_new = file_1_new.astype(str)
file_2_new = file_2_new.astype(str)
file_3_new = file_3_new.astype(str)
file_4_new = file_4_new.astype(str)
file_5_new = file_5_new.astype(str)

# %%
df_final = pd.concat([file_1_new, file_2_new, file_3_new, file_4_new, file_5_new])
df_final.head()
# Out:
#                                Chave Acesso NFe Data Emissão Número Item  \
# 0  35161071605265000919550020000014871120598054   2016-10-01           1
# 1  35161071605265000919550020000014881120599317   2016-10-01           1
# 2  35161071605265000919550020000014891120599373   2016-10-01           1
# 3  35161071605265000919550020000014901120602367   2016-10-02           1
# 4  35161071605265000919550020000014911120605207   2016-10-02           1
#
#   Código Produto ou Serviço Código CFOP (04 Posições) Quantidade Comercial  \
# 0                    824219                      1411               1,0000
# 1                     77875                      1411               1,0000
# 2                    840272                      1411               1,0000
# 3                     60046                      1411               1,0000
# 4                    817478                      1411               1,0000
#
#   Valor Produto ou Serviço Valor ICMS Operação  \
# 0                    13,02                 nan
# 1                    29,02                 nan
# 2                    21,79                 nan
# 3                     19,3                 nan
# 4                    17,15                 nan
#
#   Valor ICMS Substituição Tributária  \
# 0                                nan
# 1                                nan
# 2                                nan
# 3                                nan
# 4                                nan
#
#   Valor Base Cálculo ICMS Substituição Tributária  \
# 0                                             nan
# 1                                             nan
# 2                                             nan
# 3                                             nan
# 4                                             nan
#
#   Valor Base Cálculo ICMS ST Retido Operação Anterior  \
# 0                                              15,25
# 1                                              31,12
# 2                                              31,54
# 3                                              27,93
# 4                                              13,97
#
#                Descrição Produto     Código GTIN Unidade Comercial Código NCM  \
# 0    Pediletan Lc Cap 60ml Cimed  7896523209364             UN       30039099
# 1       Seki Xarope 120ml Zambom  7898074618183             UN       30039099
# 2         Fr Bigfral Plus Xg C/7  7896012800843             UN       96190000
# 3  Fr Capricho Sensaty Prem M 10  7891522021122             UN       96190000
# 4          Tanderalgin 12S Delta  7893454209913             UN       30039099
#
#   Código CEST Número CNPJ Emitente Número CNPJ Destinatário            Tipo
# 0   1300301.0       71605265000919                      nan  entrada_oprprp
# 1   1300101.0       71605265000919                      nan  entrada_oprprp
# 2   2005000.0       71605265000919                      nan  entrada_oprprp
# 3   2005000.0       71605265000919                      nan  entrada_oprprp
# 4   1300301.0       71605265000919                      nan  entrada_oprprp

# %%
df_final.to_csv(f'Loja_{loja}/loja_{loja}_tabela_1.csv', encoding='utf-8')
