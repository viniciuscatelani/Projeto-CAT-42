# %%
# Importação das bibliotecas necessárias

import pandas as pd
import numpy as np

# %%
# Definicção de qual loja irá rodar o script

loja = 28

# %%
# Leitura do arquivo da tabela 2

tabela_2 = pd.read_csv(f'Loja_{loja}/loja_{loja}_tabela_2_v1.csv')
tabela_2.head()
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\629038885.py:3: DtypeWarning: Columns (20,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_2 = pd.read_csv(f'Loja_{loja}/loja_{loja}_tabela_2_v1.csv')
#    Unnamed: 0                                       CHV_DOC        DATA  CFOP  \
# 0         154  35191006161357001371550020000229431157924751  2019-10-01  1411
# 1         155  35191006161357001371550020000229451157925272  2019-10-01  1411
# 2         156  35191006161357001371550020000229551157942670  2019-10-01  1411
# 3         158  35191006161357001371550020000229701157965951  2019-10-01  1411
# 4         159  35191006161357001371550020000229721157980041  2019-10-02  1411
#
#    NUM_ITEM  COD_ITEM  IND_OPER  SUB_TIPO  QTD_CAT  QTD_EFD  ...  \
# 0         1    879114         0        -1        1      NaN  ...
# 1         1    760678         0        -1        1      NaN  ...
# 2         1     46805         0        -1        1      NaN  ...
# ...

# %%
# Retirada de colunas desnecessárias e ordenação do dataframe
tabela_2 = tabela_2.drop('Unnamed: 0', axis=1)
tabela_2 = tabela_2.sort_values(by=['COD_ITEM', 'DATA', 'IND_OPER', 'SUB_TIPO'], 
                           ascending=[True, True, True, False])
tabela_2
# Out:
#                                               CHV_DOC        DATA  CFOP  \
# 19554    35191027849963000110550010005851251005832739  2019-10-16  1403
# 20711    35191027849963000110550010005864571005846114  2019-10-17  1403
# 850132   35191006161357001371590000459452376749653022  2019-10-22  5405
# 850133   35191006161357001371590000459452376749653022  2019-10-22  5405
# 850134   35191006161357001371590000459452376749653022  2019-10-22  5405
# ...                                               ...         ...   ...
# 1278870  35201206161357001371590000459452944477807768  2020-12-02  5405
# 1278871  35201206161357001371590000459452944477807768  2020-12-02  5405
# 1082981  35201206161357001371590000162453848713824403  2020-12-07  5405
# 1082982  35201206161357001371590000162453848713824403  2020-12-07  5405
# 1082983  35201206161357001371590000162453848713824403  2020-12-07  5405
#
#          NUM_ITEM  COD_ITEM  IND_OPER  SUB_TIPO  QTD_CAT  QTD_EFD  ICMS_TOT  \
# ...

# %%
# Separação do dataframe em dois diferentes para tratamento 
# e geração dos arquivos
cods = list(tabela_2['COD_ITEM'].unique())
l = len(cods)
cods_p1 = cods[:int(l/2)]
cods_p2 = cods[int(l/2):]

# %%
tabela_2_1 = tabela_2[tabela_2['COD_ITEM'].isin(cods_p1)]
tabela_2_2 = tabela_2[tabela_2['COD_ITEM'].isin(cods_p2)]

# %%
# Visualização do primeiro dataframe
tabela_2_1
# Out:
#                                               CHV_DOC        DATA  CFOP  \
# 19554    35191027849963000110550010005851251005832739  2019-10-16  1403
# 20711    35191027849963000110550010005864571005846114  2019-10-17  1403
# 850132   35191006161357001371590000459452376749653022  2019-10-22  5405
# 850133   35191006161357001371590000459452376749653022  2019-10-22  5405
# 850134   35191006161357001371590000459452376749653022  2019-10-22  5405
# ...                                               ...         ...   ...
# 900591   35201106161357001371590000162453829714741625  2020-11-28  5405
# 1056476  35201106161357001371590000459452936736637761  2020-11-30  5405
# 350622   35201227849963000110550010010019721009986165  2020-12-02  1403
# 935517   35201206161357001371590000460833867937993617  2020-12-26  5405
# 368887   35201271605265006283550010000019521010234914  2020-12-29  1403
#
#          NUM_ITEM  COD_ITEM  IND_OPER  SUB_TIPO  QTD_CAT  QTD_EFD  ICMS_TOT  \
# ...

# %%
# Visualização dos segundo dataframe
tabela_2_2
# Out:
#                                               CHV_DOC        DATA  CFOP  \
# 811125   35191106161357001371590001294192941779826503  2019-11-06  5405
# 52971    35191127849963000110550010006172341006153074  2019-11-19  1403
# 733499   35191206161357001371590000459452460308502623  2019-12-19  5405
# 88805    35191227849963000110550010006528381006507701  2019-12-21  1403
# 511466   35191206161357001371590000460833141663249088  2019-12-26  5405
# ...                                               ...         ...   ...
# 1278870  35201206161357001371590000459452944477807768  2020-12-02  5405
# 1278871  35201206161357001371590000459452944477807768  2020-12-02  5405
# 1082981  35201206161357001371590000162453848713824403  2020-12-07  5405
# 1082982  35201206161357001371590000162453848713824403  2020-12-07  5405
# 1082983  35201206161357001371590000162453848713824403  2020-12-07  5405
#
#          NUM_ITEM  COD_ITEM  IND_OPER  SUB_TIPO  QTD_CAT  QTD_EFD  ICMS_TOT  \
# ...

# %%
# Adição das informações necessárias ao dataframe 1
tabela_2_1['QTD_INI'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_INI'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['QTD_ent1_devolv_ent'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT_0'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT_ent_unit'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ULT_ICMS_TOT_ent_unit'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT_1'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['qtd_saida_1_devolv_saida'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_SAIDA_UNI'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ULT_ICMS_SAIDA_UNI'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_SAIDA'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT_PCAT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['VLR_CONFR_UNIT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ULT_VLR_CONFR_UNIT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['VLR_CONFR_1'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['QTD_SALDO'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['ICMS_TOT_SALDO'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['VLR_RESSARCIMENTO'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['VLR_COMPLEMENTO'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['COD_LEGAL_PCAT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['VLR_CONFR_PCAT'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['SALDO_FINAL_MES_QTD'] = [np.nan]*tabela_2_1.shape[0]
tabela_2_1['SALDO_FINAL_MES_ICMS'] = [np.nan]*tabela_2_1.shape[0]


tabela_2_1_final = tabela_2_1[['CHV_DOC', 'DATA', 'CFOP', 'NUM_ITEM',
                          'COD_ITEM', 'IND_OPER', 'SUB_TIPO', 'QTD_CAT',
                          'QTD_INI', 'ICMS_INI', 'QTD_ent1_devolv_ent',
                          'ICMS_TOT_0', 'ICMS_TOT_ent_unit','ULT_ICMS_TOT_ent_unit',
                          'ICMS_TOT_1', 'qtd_saida_1_devolv_saida','ICMS_SAIDA_UNI',
                          'ULT_ICMS_SAIDA_UNI', 'ICMS_SAIDA', 'ICMS_TOT_PCAT',
                          'VL_CONFR_0', 'VLR_CONFR_UNIT', 'ULT_VLR_CONFR_UNIT',
                          'VLR_CONFR_1', 'QTD_SALDO', 'ICMS_TOT_SALDO', 'VLR_RESSARCIMENTO',
                          'VLR_COMPLEMENTO', 'COD_LEGAL', 'COD_LEGAL_PCAT', 'VLR_CONFR_PCAT',
                          'SALDO_FINAL_MES_QTD', 'SALDO_FINAL_MES_ICMS','ALIQUOTA',
                          'VALOR', 'Valor Base Cálculo ICMS ST Retido Operação Anterior',
                          'Valor Complementar', 'Valor ICMS Substituição Tributária',
                          'Valor ICMS Operação', 'ICMS_TOT']]
tabela_2_1_final
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\604258699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_1['QTD_INI'] = [np.nan]*tabela_2_1.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\604258699.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_1['ICMS_INI'] = [np.nan]*tabela_2_1.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\604258699.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Adição das informações necessárias ao dataframe 2
tabela_2_2['QTD_INI'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_INI'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['QTD_ent1_devolv_ent'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT_0'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT_ent_unit'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ULT_ICMS_TOT_ent_unit'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT_1'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['qtd_saida_1_devolv_saida'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_SAIDA_UNI'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ULT_ICMS_SAIDA_UNI'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_SAIDA'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT_PCAT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['VLR_CONFR_UNIT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ULT_VLR_CONFR_UNIT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['VLR_CONFR_1'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['QTD_SALDO'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['ICMS_TOT_SALDO'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['VLR_RESSARCIMENTO'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['VLR_COMPLEMENTO'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['COD_LEGAL_PCAT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['VLR_CONFR_PCAT'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['SALDO_FINAL_MES_QTD'] = [np.nan]*tabela_2_2.shape[0]
tabela_2_2['SALDO_FINAL_MES_ICMS'] = [np.nan]*tabela_2_2.shape[0]


tabela_2_2_final = tabela_2_2[['CHV_DOC', 'DATA', 'CFOP', 'NUM_ITEM',
                          'COD_ITEM', 'IND_OPER', 'SUB_TIPO', 'QTD_CAT',
                          'QTD_INI', 'ICMS_INI', 'QTD_ent1_devolv_ent',
                          'ICMS_TOT_0', 'ICMS_TOT_ent_unit','ULT_ICMS_TOT_ent_unit',
                          'ICMS_TOT_1', 'qtd_saida_1_devolv_saida','ICMS_SAIDA_UNI',
                          'ULT_ICMS_SAIDA_UNI', 'ICMS_SAIDA', 'ICMS_TOT_PCAT',
                          'VL_CONFR_0', 'VLR_CONFR_UNIT', 'ULT_VLR_CONFR_UNIT',
                          'VLR_CONFR_1', 'QTD_SALDO', 'ICMS_TOT_SALDO', 'VLR_RESSARCIMENTO',
                          'VLR_COMPLEMENTO', 'COD_LEGAL', 'COD_LEGAL_PCAT', 'VLR_CONFR_PCAT',
                          'SALDO_FINAL_MES_QTD', 'SALDO_FINAL_MES_ICMS','ALIQUOTA',
                          'VALOR', 'Valor Base Cálculo ICMS ST Retido Operação Anterior',
                          'Valor Complementar', 'Valor ICMS Substituição Tributária',
                          'Valor ICMS Operação', 'ICMS_TOT']]
tabela_2_2_final
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3453732909.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_2['QTD_INI'] = [np.nan]*tabela_2_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3453732909.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_2['ICMS_INI'] = [np.nan]*tabela_2_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3453732909.py:4: SettingWithCopyWarning:
# ...

# %%
# Geração da sheet2 do dataframe 1
tabela_2_1_sheet_2 = tabela_2_1[['DATA', 'COD_ITEM', 'IND_OPER','SUB_TIPO', 'QTD_CAT', 'ICMS_TOT_0']]
tabela_2_1_sheet_2['ESPECIE_OPER'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
tabela_2_1_sheet_2['SALDO'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
tabela_2_1_sheet_2['SALDO_MIN'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
tabela_2_1_sheet_2['QTD_INI'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
tabela_2_1_sheet_2['VALOR_UNIT'] = [np.nan]*tabela_2_1_sheet_2.shape[0]

tabela_2_1_sheet_2_final = tabela_2_1_sheet_2[['DATA', 'COD_ITEM', 'IND_OPER', 'SUB_TIPO', 'ESPECIE_OPER',
                                           'QTD_CAT', 'ICMS_TOT_0', 'SALDO','SALDO_MIN',
                                          'QTD_INI', 'VALOR_UNIT']]

tabela_2_1_sheet_2_final
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3897520463.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_1_sheet_2['ESPECIE_OPER'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3897520463.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_1_sheet_2['SALDO'] = [np.nan]*tabela_2_1_sheet_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\3897520463.py:5: SettingWithCopyWarning:
# ...

# %%
# Geração da sheet2 do dataframe 2
tabela_2_2_sheet_2 = tabela_2_2[['DATA', 'COD_ITEM', 'IND_OPER','SUB_TIPO', 'QTD_CAT', 'ICMS_TOT_0']]
tabela_2_2_sheet_2['ESPECIE_OPER'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
tabela_2_2_sheet_2['SALDO'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
tabela_2_2_sheet_2['SALDO_MIN'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
tabela_2_2_sheet_2['QTD_INI'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
tabela_2_2_sheet_2['VALOR_UNIT'] = [np.nan]*tabela_2_2_sheet_2.shape[0]

tabela_2_2_sheet_2_final = tabela_2_2_sheet_2[['DATA', 'COD_ITEM', 'IND_OPER', 'SUB_TIPO', 'ESPECIE_OPER',
                                           'QTD_CAT', 'ICMS_TOT_0', 'SALDO','SALDO_MIN',
                                          'QTD_INI', 'VALOR_UNIT']]

tabela_2_2_sheet_2_final
# Out:
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\2176833075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_2_sheet_2['ESPECIE_OPER'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\2176833075.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabela_2_2_sheet_2['SALDO'] = [np.nan]*tabela_2_2_sheet_2.shape[0]
# C:\Users\vinic\AppData\Local\Temp\ipykernel_20836\2176833075.py:5: SettingWithCopyWarning:
# ...

# %%
# Geração do arquivo final referente ao dataframe 1
path = f'Loja_{loja}/ficha_3_loja_{loja}_p1_v1.xlsx'
with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
    tabela_2_1_final.to_excel(writer, sheet_name='ficha3', index=False)
    tabela_2_1_sheet_2_final.to_excel(writer, sheet_name='qtde', index=False)

# %%
# Geração do arquivo final referente ao dataframe 2
path = f'Loja_{loja}/ficha_3_loja_{loja}_p2_v1.xlsx'
with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
    tabela_2_2_final.to_excel(writer, sheet_name='ficha3', index=False)
    tabela_2_2_sheet_2_final.to_excel(writer, sheet_name='qtde', index=False)
